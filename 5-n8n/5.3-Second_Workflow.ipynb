# %% [markdown]
# <hr>
#
# ## Second Workflow : Trigger Email by using OpenAI Model
# <hr>

# %% [markdown]
# `Workflow Canvas`
#
# ![image-2.png](attachment:image-2.png) <hr>
#
# `On form submission`
#
# ![image-3.png](attachment:image-3.png) <hr>
#
# `Message a model`
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png) <hr>
#
# `Send a message`
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-7.png](attachment:image-7.png) <hr>
#
# ![image.png](attachment:image.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)<hr>
#
# ![image-12.png](attachment:image-12.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png) <hr>
#
# ![image-15.png](attachment:image-15.png) <hr>
