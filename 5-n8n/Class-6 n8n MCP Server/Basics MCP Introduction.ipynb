# %% [markdown]
# <hr>
#
# ### n8n MCP Server
#
# `Click here` 👉 [MCP Client Tool node](https://docs.n8n.io/integrations/builtin/cluster-nodes/sub-nodes/n8n-nodes-langchain.toolmcp/)
#
# ![image-2.png](attachment:image-2.png)
#
# <hr>
#
# ### Tavily MCP Server
#
# `Click here` 👉 [Tavily MCP Server](https://docs.tavily.com/documentation/mcp)
#
# ![image.png](attachment:image.png)
#
# `Click here` 👉 [tavily-mcp](https://github.com/tavily-ai/tavily-mcp)
#
# ![image-4.png](attachment:image-4.png) ![image-3.png](attachment:image-3.png)
#
# `Entire Workflow`
#
# ![image-5.png](attachment:image-5.png)
#
# `MCP Server Trigger -> Copy MCP URL`
#
# ![image-6.png](attachment:image-6.png)
#
# `MCP Client -> Paste MCP URL to Endpoint`
#
# ![image-8.png](attachment:image-8.png) ![image-7.png](attachment:image-7.png)
#
# #### `MCP Server`
# `MCP Server Trigger`
#
# ![image-14.png](attachment:image-14.png)
#
# `Tavily Search`
#
# ![image-15.png](attachment:image-15.png)
#
# `Dropbox`
#
# ![image-16.png](attachment:image-16.png)
#
# #### `MCP Client`
# `When Chat Message received`
#
# ![image-17.png](attachment:image-17.png)
#
# `AI Agent`
#
# ![image-18.png](attachment:image-18.png)
#
# `OpenAI Chat Model`
#
# ![image-19.png](attachment:image-19.png) ![image-20.png](attachment:image-20.png)
#
# `MCP Client`
#
# ![image-21.png](attachment:image-21.png) ![image-22.png](attachment:image-22.png)
#
# `Logs`
#
# ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png)
#
# <hr>

# %% [markdown]
# ### n8n MCP Client / Server
#
# `We can also call Tavily Tool and Dropbox within MCP Client`
#
# ![image.png](attachment:image.png)
#
# <hr>
