# %% [markdown]
# <hr>
#
# ### [Dropbox](https://www.dropbox.com)
#     1. Dropbox the cloud storage app (like Google Drive, OneDrive) → you want to use it for file sharing or syncing with GitHub.
#     2. Or you are asking about a "dropbox" style file upload UI element (like in a web app where users drag-and-drop files).
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# <hr>
