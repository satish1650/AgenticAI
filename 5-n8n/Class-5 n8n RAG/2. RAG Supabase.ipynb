# %% [markdown]
# <hr>
#
# ### n8n RAG Implementation using `Supabase`
# <hr>

# %% [markdown]
# `Dropbox Connection`
#
# ![image.png](attachment:image.png)
#
# `Download a file`
#
# ![image-2.png](attachment:image-2.png)
#
# `Download a file -> Operation`
#
# ![image-6.png](attachment:image-6.png)
#
# `update file_path as per Dropbox`
#
# ![image-5.png](attachment:image-5.png) ![image-3.png](attachment:image-3.png)
#
# `After that Execute the step`
#
# Now my file has been downloaded from `Dropbox` to `n8n`
#
# ![image-4.png](attachment:image-4.png)
#
# `Embeddings OpenAI`
#
# ![image-7.png](attachment:image-7.png)
#
# `Default Data Loader`
#
# ![image-8.png](attachment:image-8.png)
#
# `Default Data Loader -> Type of Data`
#
# ![image-9.png](attachment:image-9.png)
#
# `Default Data Loader -> Data Format`
#
# ![image-10.png](attachment:image-10.png)
#
# `Default Data Loader -> Add Options`
#
# ![image-11.png](attachment:image-11.png)
#
# `Superbase accout -> Create New Credential`
#
# ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png)
#
# `Now Goto Supabase and get API Key`
#
# ![image-14.png](attachment:image-14.png)
#
# `Connection Successfully`
#
# ![image-15.png](attachment:image-15.png)
#
# ### After connection [Copy Query](https://supabase.com/docs/guides/ai/langchain?database-method=sql)
#
# `Supabase -> SQL Editor -> Paste Query`
#
# ![image-16.png](attachment:image-16.png)
#
# `Query has been run Successfully`
#
# ![image-17.png](attachment:image-17.png)
#
# `Now documents has been Created`
#
# ![image-18.png](attachment:image-18.png)
#
# `Now My documents is appearing in the From list`
#
# ![image-19.png](attachment:image-19.png)
#
# `📚 Load Data Flow`
#
# ![image-20.png](attachment:image-20.png)
#
# `All Embeddings created for 53 itmes in Supabase`
#
# ![image-21.png](attachment:image-21.png)  ![image-22.png](attachment:image-22.png)
#
# `Retriever Flow`
#
# ![image-23.png](attachment:image-23.png)
#
#
# `Executing Entire Flow`
#
# ![image-24.png](attachment:image-24.png) ![image-25.png](attachment:image-25.png)
#
# `Logs`
#
# ![image-26.png](attachment:image-26.png)
#
# <hr>
