# %% [markdown]
# <hr>
#
# ### MCP Running on Local n8n
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png)
#
# <hr>

# %% [markdown]
# ### [tavily-mcp](https://github.com/tavily-ai/tavily-mcp)
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# <hr>

# %% [markdown]
# ### `MCP is running on Internet`
# ![image.png](attachment:image.png)
#
# ### `MCP Server is hosted on my Local and Connecting to Tavily Via API Using Internet`
# ![image-2.png](attachment:image-2.png)
#
# ### `n8n Cloud Vs. n8n on Local`
# ![image-3.png](attachment:image-3.png)
#
# #### `n8n Cloud -> MCP Client -> Endpoint & Server Transport -> [Server Sent Events(SSE), HTTP Streamable]`
# ![image-4.png](attachment:image-4.png)
#
# #### `n8n on Local -> MCP Client -> Endpoint & Server Transport -> [Server Sent Events(SSE), HTTP Streamable]`
#
# `localhost:5678 also supports both SSE & HTTP`
#
# ![image-5.png](attachment:image-5.png)
#
# `Workflow -> n8n Local`
#
# ![image-6.png](attachment:image-6.png)
#
# <hr>

# %% [markdown]
# ### n8n Local -> MCP Community Node
# ![image.png](attachment:image.png)
#
# #### `localhost:5678 -> n8n Settings -> Community Nodes`
# ![image-2.png](attachment:image-2.png)
#
# #### n8n Cloud -> Settings -> Community Nodes -> See how different from n8n Local
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# ### Resources
# - [Install and manage community nodes](https://docs.n8n.io/integrations/community-nodes/installation/)
# - [Using community nodes](https://docs.n8n.io/integrations/community-nodes/usage/)
# - [Awesome N8N: Top 100 Community Nodes](https://github.com/restyler/awesome-n8n)
#
# <hr>
