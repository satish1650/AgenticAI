# %% [markdown]
# <hr>
#
# ### Local n8n Issues
# <hr>

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)
# ![image-6.png](attachment:image-6.png) ![image-5.png](attachment:image-5.png)
#
# <hr>

# %% [markdown]
# ### Run n8n Locally in Docker
#
# `Download the Latest n8nio/n8n`
#
# ![image.png](attachment:image.png)
#
# `Run a new Container for n8n`
#
# ![image-2.png](attachment:image-2.png)
#
# `Optional Settings`
#
# ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)
#
# `Docker -> Containers -> local-n8n`
#
# ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png)
#
# `Goto -> http://localhost:5678⁠`
#
# ![image-7.png](attachment:image-7.png) ![image-8.png](attachment:image-8.png) ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png)
#
# `n8n is running Locally using Docker`
#
# ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png)
#
# `Webhook Nodes`
#
# ![image-14.png](attachment:image-14.png) ![image-15.png](attachment:image-15.png)
#
# `Webhook Nodes -> Getting Response from my Local`
#
# ![image-17.png](attachment:image-17.png) ![image-16.png](attachment:image-16.png)
#
# `Telegram -> Getting Bad Request`
#
# ![image-18.png](attachment:image-18.png)
#
# `Getting Bad Request While connecting to Telegram because of n8n connected to localhost 5678 port, Now this issue is resolved by using below:-`
#
# ### 1. [Cloudflare Tunnel](https://developers.cloudflare.com/cloudflare-one/connections/connect-networks/) - **Not Free**
#
# ![image-19.png](attachment:image-19.png) ![image-20.png](attachment:image-20.png)
#
# ### 2. [Ngrok](https://ngrok.com/) - **Free** - Provide a public URL.
#
# ![image-21.png](attachment:image-21.png) ![image-22.png](attachment:image-22.png)
#
# `Ngrok installation for Windows`
#
# ![image-23.png](attachment:image-23.png) ![image-24.png](attachment:image-24.png) ![image-25.png](attachment:image-25.png) !
#
# `Installing Ngrok using Microsoft Store`
#
# [image-26.png](attachment:image-26.png)
#
# `Ngrok installed Successfully`
#
# ![image-26.png](attachment:image-26.png) ![image-27.png](attachment:image-27.png)
#
# `After Ngrok Installation -> Authtoken`
#
# ![image-28.png](attachment:image-28.png) ![image-29.png](attachment:image-29.png)
#
# `Now, Claim Free Static Domain`
#
# ![image-30.png](attachment:image-30.png) ![image-31.png](attachment:image-31.png)
#
# `Stop the running n8n service in Docker and Run the same service again with below changes`
#
# ##### **WEBHOOK_URL = https://golden-central-lemur.ngrok-free.app
#
# ![image-32.png](attachment:image-32.png) ![image-33.png](attachment:image-33.png) ![image-34.png](attachment:image-34.png)
#
# `Use URL  http://localhost:5678/setup⁠ to access n8n workflow`
#
# ![image-35.png](attachment:image-35.png) ![image-36.png](attachment:image-36.png) ![image-37.png](attachment:image-37.png)
#
# `Webhook -> Not getting localhost:5678`
#
# ![image-38.png](attachment:image-38.png) ![image-39.png](attachment:image-39.png)
#
# `Telegram Account`
#
# ![image-40.png](attachment:image-40.png) ![image-41.png](attachment:image-41.png)
#
# ![image-42.png](attachment:image-42.png)
#
# `Copy and replace 80 with 5678 -> ngrok http --url=golden-central-lemur.ngrok-free.app 5678`
#
# ![image-44.png](attachment:image-44.png) ![image-43.png](attachment:image-43.png)
#
# `n8n-research bot`
# ![image-45.png](attachment:image-45.png)
#
# `Telegram -> Response`
#
# ![image-46.png](attachment:image-46.png)
#
# `n8n-research bot`
# ![image-47.png](attachment:image-47.png)
#
# `Telegram -> Response`
#
# ![image-48.png](attachment:image-48.png)
#
# `Webhook -> Not Got Response`
#
# ![image-50.png](attachment:image-50.png) ![image-49.png](attachment:image-49.png)
#
# `Webhook -> Now Got Response`
#
# ![image-51.png](attachment:image-51.png) ![image-52.png](attachment:image-52.png) ![image-53.png](attachment:image-53.png) ![image-54.png](attachment:image-54.png)
#
# <hr>
