# %% [markdown]
# <hr>
#
# ### [Qdrant](https://qdrant.tech/)
# ![image.png](attachment:image.png)
# <hr>

# %% [markdown]
# ### `Qdrant is running under docker.desktop`
#
# ![image-24.png](attachment:image-24.png)
#
# ![image.png](attachment:image.png)
#
# `docker.desktop -> Containers -> Qdrant -> Logs`
#
# ![image-2.png](attachment:image-2.png)
#
# `Qdrant -> localhost:6333`
#
# ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)
#
# `http://localhost:6333/dashboard -> Qdrant -> Collections`
#
# ![image-5.png](attachment:image-5.png)
#
# `Qdrant -> Collections -> Vector-db`
#
# ![image-6.png](attachment:image-6.png) ![image-7.png](attachment:image-7.png)
#
# `OPEN GRAPH`
#
# ![image-9.png](attachment:image-9.png) ![image-8.png](attachment:image-8.png) ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png) ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png)
#
# `Qdrant -> Collections -> INFO`
#
# ![image-14.png](attachment:image-14.png) ![image-15.png](attachment:image-15.png) ![image-16.png](attachment:image-16.png)
#
# ### `vector-db-2`
#
# ![image-17.png](attachment:image-17.png) ![image-18.png](attachment:image-18.png)
#
# `OPEN GRAPH`
#
# ![image-19.png](attachment:image-19.png)
#
# `vector-db-2 -> Collections -> INFO`
#
# ![image-20.png](attachment:image-20.png) ![image-21.png](attachment:image-21.png) ![image-22.png](attachment:image-22.png) ![image-23.png](attachment:image-23.png)
#
#
#
# <hr>
