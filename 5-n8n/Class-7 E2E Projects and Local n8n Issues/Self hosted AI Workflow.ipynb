# %% [markdown]
# <hr>
#
# ### n8n GitHub -> n8n-io (n8n - Workflow Automation) -> self-hosted-ai-starter-kit
# <hr>

# %% [markdown]
# `Click Here` 👉 [n8n GitHub](https://github.com/n8n-io/n8n)
#
# ![image.png](attachment:image.png)
#
# `Click on n8n-io`
#
# ![image-2.png](attachment:image-2.png)
#
# `Click Here` 👉 [n8n-io](https://github.com/n8n-io)
#
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# ### Self-hosted AI starter kit
# `Click on self-hosted-ai-starter-kit`
#
# ![image-4.png](attachment:image-4.png)
#
# `Click Here` 👉 [self-hosted-ai-starter-kit](https://github.com/n8n-io/self-hosted-ai-starter-kit)
#
# ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png) ![image-7.png](attachment:image-7.png) ![image-8.png](attachment:image-8.png) ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png)
#
# <hr>
#
# ### Installation -> Cloning the Repository
# `git clone https://github.com/n8n-io/self-hosted-ai-starter-kit.git`
#
# ![image-11.png](attachment:image-11.png)
#
# `cd self-hosted-ai-starter-kit`
#
# ![image-12.png](attachment:image-12.png)
#
# `cp .env.example .env # you should update secrets and passwords inside`
#
# ![image-13.png](attachment:image-13.png)
#
# `docker-compose.yml`
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)
#
# `Added -> ports - 5435:5435`
#
# ![image-16.png](attachment:image-16.png)
#
# `docker compose --profile cpu up -> This takes some time so wait while running this command`
#
# `Running ollam-pull-llama-cpu Pulling`
#
# ![image-33.png](attachment:image-33.png) ![image-34.png](attachment:image-34.png)
#
# ![image-17.png](attachment:image-17.png) ![image-18.png](attachment:image-18.png) ![image-35.png](attachment:image-35.png)
#
# `qdrant`
#
# ![image-21.png](attachment:image-21.png) ![image-22.png](attachment:image-22.png)
#
# `postgres`
#
# ![image-23.png](attachment:image-23.png) ![image-20.png](attachment:image-20.png)
#
# ![image-24.png](attachment:image-24.png) ![image-25.png](attachment:image-25.png) ![image-26.png](attachment:image-26.png)
#
# `docker-desktop -> self-hosted-ai-starter-kit`
#
# ![image-19.png](attachment:image-19.png) ![image-28.png](attachment:image-28.png) ![image-36.png](attachment:image-36.png)
#
# `Click on Highlighted one`
#
# ![image-27.png](attachment:image-27.png) ![image-29.png](attachment:image-29.png) ![image-30.png](attachment:image-30.png) ![image-31.png](attachment:image-31.png)
#
# `Now Qdrant is running...`
#
# ![image-32.png](attachment:image-32.png)
# <hr>

# %% [markdown]
# `Goto -> http://localhost:5678/`
#
# ![image.png](attachment:image.png)
#
# `This time It will have .env file with below details`
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# `n8n dashboard`
#
# ![image-4.png](attachment:image-4.png)
#
# `Demo Workflow`
#
# ![image-5.png](attachment:image-5.png)
#
# <hr>

# %% [markdown]
# ### n8n Ollama 3.2 Chat Model
# <hr>
#
# `Click Here` 👉 [Ollama](https://ollama.com/)
#
# ![image-9.png](attachment:image-9.png)
#
# <hr>
#
# `n8n Ollama Chat Model Workflow`
#
# ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png)
#
# `Using Below Steps to resolve above issue`
#
# ![image.png](attachment:image.png)
#
# `Ollama -> Models`
#
# ![image-2.png](attachment:image-2.png)
#
# `Ollam -> Models -> Search llama 3.2`
#
# ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)
#
# `Now Goto -> docker-desktop -> Ollama`
#
# ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png)
#
# `Goto Exec -> ollama pull llama3.2`
#
# ![image-7.png](attachment:image-7.png) ![image-8.png](attachment:image-8.png)
#
#
# `Now able to see llama3.2:latest`
#
# ![image-12.png](attachment:image-12.png)
#
# `Run the workflow with llama3.2:latest`
#
# ![image-13.png](attachment:image-13.png)
#
# `Node executed successfully with response`
#
# ![image-14.png](attachment:image-14.png) ![image-15.png](attachment:image-15.png)
#
# `When Chat Message Received`
#
# ![image-16.png](attachment:image-16.png)
#
# `AI Agent`
#
# ![image-17.png](attachment:image-17.png)
#
# `Ollama Chat Model`
#
# ![image-18.png](attachment:image-18.png)
#
# `Shutting down docker compose`
#
# ![image-19.png](attachment:image-19.png)
#
# `Everything is stopped in docker-desktop`
#
# ![image-20.png](attachment:image-20.png)
# <hr>

# %% [markdown]
# ### `Click Here` 👉 [Ngrok docker](https://hub.docker.com/r/ngrok/ngrok/tags)
# <hr>
#
# ![image.png](attachment:image.png)
#
# `Give NGROK_AUTHTOKEN and WEBHOOK_URL in .env file`
#
# ![image-6.png](attachment:image-6.png)
#
# `Ngrok -> NGROK_AUTHTOKEN`
#
# ![image-3.png](attachment:image-3.png)
#
# `WEBHOOK_URL = Ngrok -> Setup & Installation -> Deploy your app online -> Static Domain`
#
# ![image-4.png](attachment:image-4.png)
#
# `update below details in docker-compose.yml file`
#
# ![image-5.png](attachment:image-5.png)
#
# `Now run -> docker compose up to pulling Ngrok in docker-desktop`
#
# ![image-2.png](attachment:image-2.png) ![image-7.png](attachment:image-7.png) ![image-9.png](attachment:image-9.png)
#
# `docker-desktop -> Ngrok`
#
# ![image-8.png](attachment:image-8.png)
#
# `Now this time doesn't ask any email credential while using n8n, also saved all my workflow`
#
# ![image-10.png](attachment:image-10.png)
#
#
# <hr>
