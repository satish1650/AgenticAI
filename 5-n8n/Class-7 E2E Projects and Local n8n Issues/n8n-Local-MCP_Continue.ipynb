# %% [markdown]
# <hr>
#
# ### MCP Running on Local n8n
# <hr>

# %% [markdown]
# ### Resources
# - [Install and manage community nodes](https://docs.n8n.io/integrations/community-nodes/installation/)
# - [Using community nodes](https://docs.n8n.io/integrations/community-nodes/usage/)
# - [Awesome N8N: Top 100 Community Nodes](https://github.com/restyler/awesome-n8n)
#
# #### `n8n-nodes-mcp`
# ![image.png](attachment:image.png)
#
# ### Install Community Nodes Locally
# #### `n8n Local -> Settings -> Community nodes`
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png)
#
# #### `n8n Local -> We will add MCP Client which is locally installed`
# ![image-6.png](attachment:image-6.png)
#
# `Create New Credentials`
#
# ![image-7.png](attachment:image-7.png)
#
# `Command Line (STDIO)`
#
# ![image-8.png](attachment:image-8.png)
#
# `Server-Sent Events(SSE)`
#
# ![image-9.png](attachment:image-9.png)x
#
# `HTTP Streamable`
#
# ![image-10.png](attachment:image-10.png)
#
# #### `n8n Local -> MCP Client (STDIO) Account`
# ![image-17.png](attachment:image-17.png) ![image-16.png](attachment:image-16.png) ![image-18.png](attachment:image-18.png) ![image-19.png](attachment:image-19.png)
#
# `Use below Steps for n8n Local -> MCP Client Setup`
#
# ![image-11.png](attachment:image-11.png)
#
# `Tavily tick means Communit Nodes We can install from n8n`
#
# ![image-12.png](attachment:image-12.png)
#
# `Tavily Install Node`
#
# ![image-13.png](attachment:image-13.png) ![image-14.png](attachment:image-14.png)
#
# `Tavily Community Node Installed`
#
# ![image-15.png](attachment:image-15.png)
#
# <hr>

# %% [markdown]
# ### Enitre Workflow -> MCP Running on Local n8n
# ![image.png](attachment:image.png)
#
# `Executing...`
#
# ![image-2.png](attachment:image-2.png)
#
# `MCP Tavily Response...`
#
# ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)
