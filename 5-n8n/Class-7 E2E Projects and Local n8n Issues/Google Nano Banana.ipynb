# %% [markdown]
# <hr>
#
# ### Google Nano Banana -> Click Here 👉 [Google AI Studio](https://aistudio.google.com/prompts/new_chat)
# <hr>
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png) ![image-7.png](attachment:image-7.png)
#
# ### Google AI Studio -> Get API Key
# ![image-8.png](attachment:image-8.png)
#
# <hr>

# %% [markdown]
# ### Google Nano Banana overview
#
# #### `Entire Workflow`
# ![image.png](attachment:image.png)
#
# #### `Google Nano Banana -> With Images`
#
# ##### `On form submission`
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png) ![image-7.png](attachment:image-7.png)
#
# ##### `Extract From File`
# ![image-8.png](attachment:image-8.png) ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png)
#
# ##### `HTTP Request`
# ![image-11.png](attachment:image-11.png) ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png) ![image-14.png](attachment:image-14.png)
#
# #### `Convert to File`
# ![image-16.png](attachment:image-16.png) ![image-15.png](attachment:image-15.png) ![image-17.png](attachment:image-17.png)
#
# #### `Google Nano Banana -> With Images`
#
# ##### `Entire Workflow`
# ![image-18.png](attachment:image-18.png)
#
# ##### `When Chat Message Received`
# ![image-19.png](attachment:image-19.png)
#
# ##### `HTTP Request`
# ![image-20.png](attachment:image-20.png) ![image-21.png](attachment:image-21.png) ![image-22.png](attachment:image-22.png)
#
# ##### `Convert to File`
# ![image-23.png](attachment:image-23.png) ![image-24.png](attachment:image-24.png) ![image-25.png](attachment:image-25.png) ![image-26.png](attachment:image-26.png)
#
# ##### `Downloaded the file as txt file`
# ![image-27.png](attachment:image-27.png)
# <hr>

# %% [markdown]
# ### AI Video Generation APIs Click Here 👉 [KEI API](https://kie.ai/)
#
# Create high-quality videos with Veo 3, Veo 3 Fast, and Runway Aleph. Veo 3 offers synchronized audio, smooth motion, and realistic scenes, while Veo 3 Fast delivers quicker, lower-cost rendering. Runway Aleph adds advanced scene reasoning and precise camera control — choose the best fit for your project.
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)
# <hr>
