# %% [markdown]
# <hr>
#
# ![image.png](attachment:image.png)
# <hr>

# %% [markdown]
# ### Ngrok, Postgres, Qdrant, n8n and Ollama Chat Model are running under docker container
# <hr>
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ### `n8n is running locally`
#
# ![image-3.png](attachment:image-3.png)
#
# ### `Qdrant is running locally`
#
# ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png) ![image-6.png](attachment:image-6.png)
#
# ### `Ollama is running locally`
#
# ![image-7.png](attachment:image-7.png)
#
# <hr>

# %% [markdown]
# ### `RAG - On Local in n8n usig Qdrant`
# ![image-9.png](attachment:image-9.png)
#
# ### `Ollama Embedding`
# ![image.png](attachment:image.png)
#
# `Copy -> ollama pull mxbai-embed-large`
#
# ![image-2.png](attachment:image-2.png)
#
# `Paste -> docker container`
#
# ![image-3.png](attachment:image-3.png)
#
# `Select -> mxbai-embed-large:latest`
#
# ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png)
#
# `Execute Qdrant Vector Store`
#
# ![image-6.png](attachment:image-6.png)
#
# `Entire Workflow is running`
#
# ![image-8.png](attachment:image-8.png)
#
# `Embeddings Successfully completed`
#
# ![image-7.png](attachment:image-7.png)
#
# `Goto -> Qdrant -> Collections`
#
# ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png)
#
# `Qdrant -> Collections -> vector-db`
#
# ![image-12.png](attachment:image-12.png) ![image-13.png](attachment:image-13.png)
#
# `vector-db -> open graph`
#
# ![image-14.png](attachment:image-14.png) ![image-15.png](attachment:image-15.png) ![image-16.png](attachment:image-16.png)
# ![image-17.png](attachment:image-17.png) ![image-18.png](attachment:image-18.png) ![image-19.png](attachment:image-19.png)
# <hr>

# %% [markdown]
# ### `RAG - On Local in n8n using Qdrant`
#
# ![image-3.png](attachment:image-3.png) ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
#
# `On Form Submission`
#
# ![image-4.png](attachment:image-4.png)
#
# `Qdrant Vector Store`
#
# ![image-5.png](attachment:image-5.png)
#
# `Default Document Loader`
#
# ![image-6.png](attachment:image-6.png)
#
# `Embeddings Ollama`
#
# ![image-7.png](attachment:image-7.png) ![image-8.png](attachment:image-8.png)
#
# `When Chat Message Received`
#
# ![image-9.png](attachment:image-9.png)
#
# `AI Agent`
#
# ![image-10.png](attachment:image-10.png) ![image-11.png](attachment:image-11.png)
#
# `Ollama Chat Model`
#
# ![image-12.png](attachment:image-12.png)
#
# `Open AI Chat Model`
#
# ![image-13.png](attachment:image-13.png) ![image-14.png](attachment:image-14.png)
#
# `Simple Memory`
#
# ![image-18.png](attachment:image-18.png) ![image-19.png](attachment:image-19.png) ![image-20.png](attachment:image-20.png)
# ![image-21.png](attachment:image-21.png)
#
# `Qdrant Vector store`
#
# ![image-15.png](attachment:image-15.png) ![image-16.png](attachment:image-16.png) ![image-17.png](attachment:image-17.png)
#
# `Logs`
#
# ![image-22.png](attachment:image-22.png) ![image-23.png](attachment:image-23.png) ![image-24.png](attachment:image-24.png)
# ![image-25.png](attachment:image-25.png) ![image-26.png](attachment:image-26.png) ![image-27.png](attachment:image-27.png)
# ![image-28.png](attachment:image-28.png) ![image-29.png](attachment:image-29.png) ![image-30.png](attachment:image-30.png)
# ![image-31.png](attachment:image-31.png) ![image-32.png](attachment:image-32.png) ![image-33.png](attachment:image-33.png)
# <hr>
