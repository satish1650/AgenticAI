# %% [markdown]
# <hr>
#
# ### n8n Multi-Agents Architecture
# <hr>

# %% [markdown]
# #### 1. Automation
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# #### 2. AI Automation
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# <hr>
#
# #### 3. Agentic AI Automation
# ![image-6.png](attachment:image-6.png)
#
# ![image-17.png](attachment:image-17.png)
#
# <hr>
#
# #### 4. Mutli Agent System
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-13.png](attachment:image-13.png)
#
# #### 4.1. Multi Agent System Architecture
# ![image-12.png](attachment:image-12.png)
#
# <hr>
#
# #### `Automation to Agents`
# ![image-10.png](attachment:image-10.png)
# ![image-17.png](attachment:image-17.png)
# ![image-16.png](attachment:image-16.png)
#
#
# ![image-7.png](attachment:image-7.png)
#
# <hr>

# %% [markdown]
# <hr>
#
# ### Agent With Many Tools
# The problem which we get when we don’t use multi-agent architectures. It can hallucinate and give wrong results and not accessing
# calendar before replying to my appointment email and of course not robust enough.
# <hr>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# `Agent With Many Tools`
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <hr>
#
# #### Types of Multi-Agents
#
# #### 4.1.1 Chain of Agents
# Each agent will be configured with different brains, different prompt and different toolset much like us humans thus making sure that the output is based on the expertise.
#
# ![image.png](attachment:image.png)
#
# `Chain of Agents`
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
# ![image-8.png](attachment:image-8.png)
#
#
# `Entire Workflow`
#
# ![image-6.png](attachment:image-6.png)
# <hr>
