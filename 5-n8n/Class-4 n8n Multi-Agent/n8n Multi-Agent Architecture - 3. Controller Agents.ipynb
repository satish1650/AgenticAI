# %% [markdown]
# <hr>
#
# ### n8n Multi-Agents Architecture
# <hr>

# %% [markdown]
# #### 1. Automation
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# #### 2. AI Automation
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# <hr>
#
# #### 3. Agentic AI Automation
# ![image-6.png](attachment:image-6.png)
#
# ![image-17.png](attachment:image-17.png)
#
# <hr>
#
# #### 4. Mutli Agent System
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-13.png](attachment:image-13.png)
#
# #### 4.1. Multi Agent System Architecture
# ![image-12.png](attachment:image-12.png)
#
# <hr>
#
# #### `Automation to Agents`
# ![image-10.png](attachment:image-10.png)
# ![image-17.png](attachment:image-17.png)
# ![image-16.png](attachment:image-16.png)
#
#
# ![image-7.png](attachment:image-7.png)
#
# <hr>

# %% [markdown]
# <hr>
#
# #### Types of Multi-Agents
#
# #### 4.1.3 Controller Agents
# ![image-70.png](attachment:image-70.png)
#
# `Controller Agents`
#
# ![image-73.png](attachment:image-73.png)
#
# ![image-74.png](attachment:image-74.png)
#
# `Entire Workflow`
#
# ![image-75.png](attachment:image-75.png)
#
# ![image-76.png](attachment:image-76.png)
#
# ![image-77.png](attachment:image-77.png)
#
# ![image-78.png](attachment:image-78.png)
#
# ![image-79.png](attachment:image-79.png)
#
# ![image-80.png](attachment:image-80.png)
#
# `Controller Agents`
#
# ![image-81.png](attachment:image-81.png)
#
# <hr>
