# %% [markdown]
# <hr>
#
# #### Personal Assistant using Telegram
# <hr>

# %% [markdown]
# <hr>
#
# ![image.png](attachment:image.png)
#
# <hr>

# %% [markdown]
# <hr>
#
# #### `AI vs Agent`
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# <hr>

# %% [markdown]
# <hr>
#
# #### `Slack api` https://api.slack.com/
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# <hr>

# %% [markdown]
# <hr>
#
# ### `Telegram` https://telegram.org/
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# <hr>

# %% [markdown]
# #### `Telegram Trigger`
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
#
# #### `Credential to connect Telegram`
# ![image-4.png](attachment:image-4.png)
#
# #### `Create new credential`
# ![image-5.png](attachment:image-5.png)
#
# <hr>

# %% [markdown]
# <hr>
#
# ### `Telegram Trigger`
# ![image-2.png](attachment:image-2.png)
#
# ### `Telegram Bot Father`
# `/start`
# ![image.png](attachment:image.png)
#
# `/newbot`
# ![image-3.png](attachment:image-3.png)
#
# `bot_name -> agentic_2_bot`
# ![image-4.png](attachment:image-4.png)
#
# `user_name -> agentic_user_bot`
# ![image-5.png](attachment:image-5.png)
#
# `user_name -> agentic_smart_bot`
# ![image-6.png](attachment:image-6.png)
#
# `bot_name -> agentic_2_bot`
# ![image-7.png](attachment:image-7.png)
#
# #### `Create new credential`
# ![image-8.png](attachment:image-8.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-9.png](attachment:image-9.png)
#
# #### `Connection tested successfully`
# ![image-11.png](attachment:image-11.png)
#
# `/start agentic_2_bot`
# ![image-12.png](attachment:image-12.png)
#
# `Execute Telegram Trigger Step`
# ![image-13.png](attachment:image-13.png)
#
# `agentic_2_bot -> Hi How are you?`
# ![image-14.png](attachment:image-14.png)
#
# `Execute Telegram Trigger Step`
# ![image-15.png](attachment:image-15.png)
#
# `agentic_2_bot -> I am fine...What about you?`
# ![image-16.png](attachment:image-16.png)
#
# `Execute Telegram Trigger Step`
# ![image-17.png](attachment:image-17.png)
# <hr>
