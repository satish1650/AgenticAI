# %% [markdown]
# <hr>
#
# ### Run n8n locally and on cloud | AI Automation | Hosting
# <hr>
#
# ![image.png](attachment:image.png)
#
# <hr>

# %% [markdown]
# #### `Resources`
#
# https://www.youtube.com/watch?v=q2mezGkjbbw
#
# <hr>

# %% [markdown]
# #### `n8n run on`
#
# 1. 14-Days free trail with 1000 free iterations.
# 2. Using Docker on our Local.
# 3. On Cloud Server or machine.
#
# <hr>

# %% [markdown]
# #### 1. Natively
#
# `We can register with email_id and start working on n8n website`
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
# <hr>

# %% [markdown]
# #### 2. Using Docker on our Local
#
# `Docker Desktop Home page`
#
# ![image.png](attachment:image.png)
#
# `Go and search n8n, select latest one as below`
#
# ![image-2.png](attachment:image-2.png)
#
# `Now n8n has been pulled on my docker-desktop under Images`
#
# ![image-3.png](attachment:image-3.png)
#
# `Now we can select Run`
#
# ![image-4.png](attachment:image-4.png)
#
# `Now Run new container`
#
# ![image-5.png](attachment:image-5.png)
#
# `container name = n8n-latest and ports=5678`
#
# ![image-7.png](attachment:image-7.png)
#
# `After Run`
#
# ![image-6.png](attachment:image-6.png)
#
# `Editor is now accessible via: http://localhost:5678⁠`
#
# ![image-8.png](attachment:image-8.png)
#
# `After enter email details`
#
# ![image-9.png](attachment:image-9.png)
#
# `n8n workflow dashboard`
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
# <hr>

# %% [markdown]
# <hr>
#
# #### 3. On Cloud Server or machine (AWS, GCP, Azure, Heroku, Hostinger, digital ocean)
#
# #### [Render](https://render.com/)
#
# ![image.png](attachment:image.png)
#
# `Click on -> Get Started`
#
# ![image-2.png](attachment:image-2.png)
#
# `sign-in to render using email`
#
# ![image-3.png](attachment:image-3.png)
#
# `code's workspace`
#
# ![image-4.png](attachment:image-4.png)
#
# `Selct Web Services`
#
# ![image-5.png](attachment:image-5.png)
#
# `New Web Service`
#
# ![image-6.png](attachment:image-6.png)
#
# `Select "Publit Git Repository" and Give n8n GitHub URL (https://github.com/n8n-io/n8n)`
#
# ![image-7.png](attachment:image-7.png)
#
# `Now Connect`
#
# ![image-8.png](attachment:image-8.png)
#
# `Select Existing Image`
#
# ![image-9.png](attachment:image-9.png)
#
# `Give the URL (docker.n8n.io/n8nio/n8n) to connect with Existing Image`
#
# ![image-9.png](attachment:image-9.png)
#
# `Now Connect`
#
# ![image-10.png](attachment:image-10.png)
#
# `Now select Free`
#
# ![image-11.png](attachment:image-11.png)
#
# `Environment Variables`
#
# ![image-12.png](attachment:image-12.png)
#
# `Select Free and click on "Deploy Web Services"`
#
# ![image-13.png](attachment:image-13.png)
#
# `n8n Service is getting started...`
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)
#
# `in-Progress`
#
# ![image-16.png](attachment:image-16.png)
#
# `Now n8n is running on render`
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-18.png](attachment:image-18.png)
#
# `https://n8n-39hi.onrender.com`
#
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
#
# `Workflows - n8n`
#
# ![image-21.png](attachment:image-21.png)
#
# `skip`
#
# ![image-22.png](attachment:image-22.png)
#
# `Workflows`
#
# ![image-23.png](attachment:image-23.png)
#
# `My Workflow`
#
# ![image-25.png](attachment:image-25.png)
#
# ![image-24.png](attachment:image-24.png)
#
# `Suspend n8n Services`
#
# ![image-26.png](attachment:image-26.png)
#
# ![image-28.png](attachment:image-28.png)
#
# `Suspended n8n Services`
#
# ![image-27.png](attachment:image-27.png)
#
# ![image-29.png](attachment:image-29.png)
#
# ![image-30.png](attachment:image-30.png)
# <hr>
