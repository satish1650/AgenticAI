# %% [markdown]
# <hr>
#
# ## Nodes in n8n
# <hr>

# %% [markdown]
# `Workflow canvas`
#
# ![image-6.png](attachment:image-6.png) <hr>
#
# `Trigger Node`
#
# ![image.png](attachment:image.png) <hr>
#
# `Action Node`
#
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) <hr>
#
# `I am a note`
#
# ![image-4.png](attachment:image-4.png) <hr>
#
# `Action Node`
#
# ![image-5.png](attachment:image-5.png) <hr>
