# %%
import os
from pathlib import Path

# Store in project directory
try:
    # This works when running as a script file
    project_root = Path(__file__).parent
except NameError:
    # This works in interactive environments
    project_root = Path.cwd()

storage_dir = project_root / "crewal_storage"

os.environ["CREWAL_STORAGE_DIR"] = str(storage_dir)

# Now all storage will be in your project directory

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from crewai import Crew, Agent, Task, Process

# Define a simple agent (assuming a default LLM agent)
assistant = Agent(role="Personal Assistant",
                  goal="""You are a personal assistant that can
                          help the user with their tasks.""",
                  backstory="""You are a personal assistant that
                               can help the user with their tasks.""",
                  verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=assistant)

# Create a crew with memory enabled
crew = Crew(
    agents=[assistant], 
    tasks=[task], 
    process=Process.sequential,
    verbose=True
)
# Out:
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCAF887D0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.99999213218689)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCAF88B90>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999995708465576)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCC598550>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999996423721313)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCC599590>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999995231628418)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCC598550>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999963998794556)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCC5996D0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.99999737739563)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCCC598690>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999996185302734)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCC84811D0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.99999737739563)'))

# %%
user_input = """My favorite color is #46778F and
                my favorite Agent framework is CrewAI."""

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3920bbaa-7845-4368-b26d-9e754f083d48                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F and                                                       │
# │                  my favorite Agent framework is CrewAI.                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F and your favorite agent framework is CrewAI.                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 027342cd-5d05-4f66-a500-9faef9ae079d                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 3920bbaa-7845-4368-b26d-9e754f083d48                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is #46778F and your favorite agent framework is CrewAI.                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
user_input = "What is my favorite color?"

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3920bbaa-7845-4368-b26d-9e754f083d48                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is [insert your favorite color here].                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 027342cd-5d05-4f66-a500-9faef9ae079d                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 3920bbaa-7845-4368-b26d-9e754f083d48                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is [insert your favorite color here].                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ---

# %% [markdown]
# ### Short Term Memory

# %%
from crewai import Crew, Agent, Task, Process

# Define a simple agent (assuming a default LLM agent)
assistant = Agent(role="Personal Assistant",
                  goal="""You are a personal assistant that can
                          help the user with their tasks.""",
                  backstory="""You are a personal assistant that
                               can help the user with their tasks.""",
                  verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=assistant)

# Create a crew with memory enabled
crew = Crew(
    agents=[assistant], 
    tasks=[task], 
    process=Process.sequential,
    memory=True, # By default all types of memory (Short Term, Long Term and Entity Memory) are enable
    verbose=True
)

# %%
user_input = """My favorite color is #46778F and
                my favorite Agent framework is CrewAI."""

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: b170c1d4-a347-4b7b-98cc-6b5908787bbd                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────────── 🧠 Retrieved Memory ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Historical Data:                                                                                               │
# │  - Ensure a direct response to the task without unnecessary preambles.                                          │
# │  - Simplify the answer to focus on the key information requested.                                               │
# │  - Ensure that descriptive parts pertain directly to the entities mentioned in the task.                        │
# │  Recent Insights:                                                                                               │
# │  - I now can give a great answer                                                                                │
# │  Final Answer: Your favorite color is #46778F, which is a refreshing shade of blue-green, reminiscent of        │
# │  tranquil waters. Your favorite agent framework is CrewAI, known for its versatility and effectiveness ...      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────── Retrieval Time: 1903.92ms ───────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F and                                                       │
# │                  my favorite Agent framework is CrewAI.                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by
# ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BCC8482850>, 'Connection to
# telemetry.crewai.com timed out. (connect timeout=29.999994039535522)'))
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F, which is a refreshing shade of blue-green, reminiscent of tranquil waters.     │
# │  Your favorite agent framework is CrewAI, known for its versatility and effectiveness in managing               │
# │  collaborative tasks and workflows.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 280ebff4-67de-462b-98aa-2e1853b8c83e                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: b170c1d4-a347-4b7b-98cc-6b5908787bbd                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is #46778F, which is a refreshing shade of blue-green, reminiscent of        │
# │  tranquil waters. Your favorite agent framework is CrewAI, known for its versatility and effectiveness in       │
# │  managing collaborative tasks and workflows.                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
user_input = "What is my favorite color?"

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: b170c1d4-a347-4b7b-98cc-6b5908787bbd                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────────── 🧠 Retrieved Memory ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Historical Data:                                                                                               │
# │  - Provide a direct answer to the question without additional commentary or unrelated details.                  │
# │  - Ensure the answer is in line with the expected output, which is to clearly state the favorite color if       │
# │  applicable.                                                                                                    │
# │  - Encourage the user to disclose their favorite color directly rather than stating it was not mentioned.       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────── Retrieval Time: 1029.88ms ───────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Please share what your favorite color is!                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 280ebff4-67de-462b-98aa-2e1853b8c83e                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: b170c1d4-a347-4b7b-98cc-6b5908787bbd                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Please share what your favorite color is!                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
crew._short_term_memory
# Out:
# ShortTermMemory(embedder_config=None, crew=None, storage=<crewai.memory.storage.rag_storage.RAGStorage object at 0x000001BCC8060050>)

# %%
user_input = "What is my favorite color?"

crew._short_term_memory.storage.search(user_input)
# Out:
# []

# %%
crew._long_term_memory.search(user_input)

# %%
user_input = "What is my favorite color?"

crew._entity_memory.search(user_input)
# Out:
# []

# %%
crew._entity_memory.search(user_input)
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# ### More on Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import ShortTermMemory
from crewai.memory.storage.rag_storage import RAGStorage

shared_db = "./short_term_memory.db"

storage = RAGStorage(path=shared_db, type="short_term")

short_term_memory = ShortTermMemory(storage=storage)

# %%
agent = Agent(role="A Personal Assistant",
              goal="""You are a personal assistant that can
                      help the user with their tasks.""",
              backstory="""You are a personal assistant that
                           can help the user with their tasks.""",
              verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent)


crew = Crew(
    agents=[agent], 
    tasks=[task], 
    process=Process.sequential,
    memory=True,
    short_term_memory=short_term_memory
)
crew.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F, which is a shade of blue with a hint of green, often associated with calmness  │
# │  and tranquility.                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is #46778F, which is a shade of blue with a hint of green, often associated with calmness and tranquility.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name='Handle this task: My favorite color is #46778F.', expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is #46778F, which is a shade of blue with a hint of green, often associated with calmness and tranquility.', pydantic=None, json_dict=None, agent='A Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=236, prompt_tokens=196, cached_prompt_tokens=0, completion_tokens=40, successful_requests=1))

# %%
user_query = "What is my favorite color?"

crew.kickoff(inputs={"user_task": user_query})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is not directly mentioned in the information provided. Please share your favorite color    │
# │  for a clear response.                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is not directly mentioned in the information provided. Please share your favorite color for a clear response.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: What is my favorite color?', name='Handle this task: What is my favorite color?', expected_output='A clear and concise answer to the question.', summary='Handle this task: What is my favorite color?...', raw='Your favorite color is not directly mentioned in the information provided. Please share your favorite color for a clear response.', pydantic=None, json_dict=None, agent='A Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=555, prompt_tokens=502, cached_prompt_tokens=0, completion_tokens=53, successful_requests=2))

# %% [markdown]
# ---

# %% [markdown]
# ### Long Term Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import LongTermMemory
from crewai.memory.storage.ltm_sqlite_storage import LTMSQLiteStorage

# %%
shared_db = "./agent_memory.db"

storage = LTMSQLiteStorage(db_path=shared_db)

long_memory = LongTermMemory(storage=storage)

# %%
agent1 = Agent(role="First Personal Assistant",
              goal="""You are a personal assistant that handles
                      user's tasks.""",
              backstory="""You are a personal assistant that
                           can help the user with their tasks.""",
              verbose=True)

task1 = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent1)

crew1 = Crew(
    agents=[agent1],
    tasks=[task1], 
    process=Process.sequential,
    memory=True,
    long_term_memory=long_memory
)
crew1.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name='Handle this task: My favorite color is #46778F.', expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, agent='First Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=265, prompt_tokens=245, cached_prompt_tokens=0, completion_tokens=20, successful_requests=1))

# %%
import sqlite3

conn = sqlite3.connect("agent_memory.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()

print("Tables in the database:")
for table in tables:
    print(table[0])

cursor.execute("SELECT * FROM long_term_memories;")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# Tables in the database:
# long_term_memories
# sqlite_sequence
# (1, 'Handle this task: My favorite color is #46778F.', '{"suggestions": ["Provide a more direct answer without additional explanations or details unless requested.", "Ensure that the response aligns closely with the task description and expected output.", "Adhere strictly to the expected output format for clarity and conciseness."], "quality": 6.0, "agent": "First Personal Assistant", "expected_output": "A clear and concise answer to the question."}', '1760722488.1228743', 6.0)
# (2, 'Handle this task: What is my favorite color?', '{"suggestions": ["Provide explicit information or context about the favorite color to obtain a precise answer.", "Avoid vague language and ensure to ask for the specific information needed.", "If a favorite color is not known, suggest common colors as examples to facilitate the response."], "quality": 4.0, "agent": "First Personal Assistant", "expected_output": "A clear and concise answer to the question."}', '1760722505.8825543', 4.0)
# (3, 'Handle this task: My favorite color is #46778F.', '{"suggestions": ["Provide a more specific prompt that requires only a definitive answer.", "Encourage concise responses without unnecessary elaboration.", "Clarify that the task requires extracting information without additional commentary."], "quality": 5.0, "agent": "First Personal Assistant", "expected_output": "A clear and concise answer to the question."}', '1760723113.526193', 5.0)

# %%
task2 = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent1)

crew2 = Crew(
    agents=[agent1], 
    tasks=[task2], 
    process=Process.sequential,
    memory=True,
    long_term_memory=long_memory
)

crew2.kickoff(inputs={"user_task": "What is my favorite color?"})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  To accurately determine your favorite color, I need you to provide that specific information. If you do not    │
# │  know or want to choose from common options, some popular favorite colors include blue, red, green, yellow,     │
# │  and purple. Please let me know your favorite!                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='To accurately determine your favorite color, I need you to provide that specific information. If you do not know or want to choose from common options, some popular favorite colors include blue, red, green, yellow, and purple. Please let me know your favorite!', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: What is my favorite color?', name='Handle this task: What is my favorite color?', expected_output='A clear and concise answer to the question.', summary='Handle this task: What is my favorite color?...', raw='To accurately determine your favorite color, I need you to provide that specific information. If you do not know or want to choose from common options, some popular favorite colors include blue, red, green, yellow, and purple. Please let me know your favorite!', pydantic=None, json_dict=None, agent='First Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=574, prompt_tokens=491, cached_prompt_tokens=0, completion_tokens=83, successful_requests=2))

# %% [markdown]
# ---

# %% [markdown]
# ### Entity Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import EntityMemory
from crewai.memory.storage.rag_storage import RAGStorage

shared_db = "./agent1_entity_memory.db"

storage = RAGStorage(path=shared_db, type="short_term")

entity_memory = EntityMemory(storage=storage)

# %%
remembering_agent = Agent(role="Remembering Agent",
                          goal="""You are a assistant that can
                                  remember the user's information.""",
                          backstory="""You are a assistant that can remember
                                       the user's information.""",
                          verbose=True)
            
task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=remembering_agent)

crew = Crew(
    agents=[remembering_agent], 
    tasks=[task], 
    process=Process.sequential,
    memory=True,
    entity_memory=entity_memory
)

crew.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Remembering Agent                                                                                       │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Remembering Agent                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name='Handle this task: My favorite color is #46778F.', expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, agent='Remembering Agent', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=254, prompt_tokens=234, cached_prompt_tokens=0, completion_tokens=20, successful_requests=1))

# %%
crew._entity_memory.search("What is my favorite color?")
# Out:
# [{'id': '85e50b730298afa3df98490ad1b6a2408e1c443b1df160d1d3455cbce2812946',
#   'content': 'I now can give a great answer  \nFinal Answer: Your favorite color is #46778F, which is a shade of blue with a hint of green, often associated with calmness and tranquility.',
#   'metadata': {'observation': 'Handle this task: My favorite color is #46778F.'},
#   'score': 0.6027024951209998}]

# %% [markdown]
# ---

# %% [markdown]
# ### Resetting Memory

# %% [markdown]
# #### [CrewAI Memory GitHub](https://github.com/crewAIInc/crewAI/tree/main/src/crewai/memory)
# ![image.png](attachment:image.png)

# %%
crew.reset_memories(command_type = 'all')

# %%
crew.reset_memories(command_type='short')

# %%
crew.reset_memories(command_type='long')

# %%
crew.reset_memories(command_type='entity')

# %% [markdown]
# ---

# %%
from crewai.utilities.paths import db_storage_path
import os

# Get the base storage path
storage_path = db_storage_path()
print(f"CrewAI storage location: {storage_path}")

# List all CrewAI storage directories
if os.path.exists(storage_path):
    print("\nStored files and directories:")
    for item in os.listdir(storage_path):
        item_path = os.path.join(storage_path, item)
        if os.path.isdir(item_path):
            print(f"📁 {item}/")
            # Show ChromaDB collections
            if os.path.exists(item_path):
                for subitem in os.listdir(item_path):
                    print(f"   └── {subitem}")
        else:
            print(f"📄 {item}")
else:
    print("No CrewAI storage directory found yet.")
# Out:
# CrewAI storage location: C:\Users\Satish\AppData\Local\CrewAI\7.2-CrewAI Advanced
#
# Stored files and directories:
# 📄 .crewai_user.json
# 📁 2794ce02-1f86-4ef3-a055-5cd7732ab834/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📁 380ad921-b18d-431f-b384-f70186f69c8f/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📁 413cd225-fb76-47d4-8f74-68d2a3daf785/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📁 71bf73ec-3c7e-41c6-a471-d1d2cc6f28e4/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📁 b28d399b-e2f7-4f07-b9fb-35c0385642dd/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📄 chroma.sqlite3
# 📄 chromadb-46091a718490a5f0f6038d4e0b0023db.lock
# 📁 d3239ead-a1de-4e59-bf3a-00f86219da79/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📁 d9520b7f-d315-4f2f-a3eb-bf5f38e5cef4/
#    └── data_level0.bin
#    └── header.bin
#    └── length.bin
#    └── link_lists.bin
# 📄 latest_kickoff_task_outputs.db
# 📄 long_term_memory_storage.db

# %% [markdown]
# ---

# %%
import os
from pathlib import Path

# Store in project directory
project_root = Path(__file__).parent
storage_dir = project_root / "crewai_storage"

os.environ["CREWAI_STORAGE_DIR"] = str(storage_dir)

# Now all storage will be in your project directory

# %% [markdown]
# ---
