# %% [markdown]
# ---
# # CrewAI Tools

# %%
import os 
from crewai import Agent, Task, Crew, LLM
from crewai_tools import SerperDevTool
from dotenv import load_dotenv

load_dotenv()
google_api_key = os.getenv("GOOGLE_API_KEY")
serper_api_key = os.getenv("SERPER_API_KEY")
os.environ["CREWAI_TELEMETRY_DISABLED"] = "true"

llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key=google_api_key
)

# Topic
topic = "AI in Healthcare"

# Tool
search_tool = SerperDevTool(n=2)

# Agent: 1 -> Senior Research Analyst
senior_research_analyst = Agent(
    role = "Senior Research Analyst",
    goal= f"Research, analyze, and synthesize comprehensive information on {topic} from reliable web sources",
    backstory="You're an expert research analyst with advanced web research skills. "
                    "You excel at finding, analyzing, and synthesizing information from "
                    "across the internet using search tools. You're skilled at "
                    "distinguishing reliable sources from unreliable ones, "
                    "fact-checking, cross-referencing information, and "
                    "identifying key patterns and insights. You provide "
                    "well-organized research briefs with proper citations "
                    "and source verification. Your analysis includes both "
                    "raw data and interpreted insights, making complex "
                    "information accessible and actionable.",
    verbose = True,
    allow_delegation=False,
    tools = [search_tool],
    llm = llm
)

# Agent: 2 -> Content Writer
content_writer = Agent(
    role="Content Writer",
    goal="Transform research findings into engaging blog posts while maintaining accuracy",
    backstory="You're a skilled content writer specialized in creating "
                    "engaging, accessible content from technical research. "
                    "You work closely with the Senior Research Analyst and excel at maintaining the perfect "
                    "balance between informative and entertaining writing, "
                    "while ensuring all facts and citations from the research "
                    "are properly incorporated. You have a talent for making "
                    "complex topics approachable without oversimplifying them.",
    verbose=True,
    allow_delegation=False,
    llm = llm
)

# Task: 1 -> Senior Research Analyst's Task
research_tasks = Task(
    description=("""
            1. Conduct comprehensive research on {topic} including:
                - Recent developments and news
                - Key industry trends and innovations
                - Expert opinions and analyses
                - Statistical data and market insights
            2. Evaluate source credibility and fact-check all information
            3. Organize findings into a structured research brief
            4. Include all relevant citations and sources
        """),
    expected_output = """A detailed research report containing:
            - Executive summary of key findings
            - Comprehensive analysis of current trends and developments
            - List of verified facts and statistics
            - All citations and links to original sources
            - Clear categorization of main themes and patterns
            Please format with clear sections and bullet points for easy reference.""",
    agent = senior_research_analyst)

# Task: 2 -> Content Writer's Task is Content Writing
writing_task = Task(
        description=("""
            Using the research brief provided, create an engaging blog post that:
            1. Transforms technical information into accessible content
            2. Maintains all factual accuracy and citations from the research
            3. Includes:
                - Attention-grabbing introduction
                - Well-structured body sections with clear headings
                - Compelling conclusion
            4. Preserves all source citations in [Source: URL] format
            5. Includes a References section at the end
        """),
        expected_output = """A polished blog post in markdown format that:
            - Engages readers while maintaining accuracy
            - Contains properly structured sections
            - Includes Inline citations hyperlinked to the original source url
            - Presents information in an accessible yet informative way
            - Follows proper markdown formatting, use H1 for the title and H3 for the sub-sections""",
        agent = content_writer)

crew = Crew(
    agents= [senior_research_analyst, content_writer],
    tasks= [research_tasks, writing_task],
    verbose = True
)

result = crew.kickoff(
    inputs={
        "topic": topic
    }
)

print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 94cd32cd-b46e-4e3b-aeea-757a5cfeefbb                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │              1. Conduct comprehensive research on AI in Healthcare including:                                   │
# │                  - Recent developments and news                                                                 │
# │                  - Key industry trends and innovations                                                          │
# │                  - Expert opinions and analyses                                                                 │
# │                  - Statistical data and market insights                                                         │
# │              2. Evaluate source credibility and fact-check all information                                      │
# │              3. Organize findings into a structured research brief                                              │
# │              4. Include all relevant citations and sources                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Satish\AgenticAI2.0\AgenticAI\my-crewai-venv\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"AI in Healthcare recent developments and news\"}"                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'AI in Healthcare recent developments and news', 'type': 'search', 'num': 10,       │
# │  'engine': 'google'}, 'organic': [{'title': 'Artificial Intelligence', 'link':                                  │
# │  'https://www.healthcareitnews.com/topics/artificial-intelligence', 'snippet': 'A new tool – with precise       │
# │  procedure details, appropriate codes and complete clinical justification automatically captured – has enabled  │
# │  more exact EHR notes.', 'position': 1}, {'title': 'The Latest AI News + Breakthroughs in Healthcare and ...',  │
# │  'link': 'https://www.crescendo.ai/news/ai-in-healthcare-news', 'snippet': 'In this article, we have explored   │
# │  the most recent innovations, funding announcements, and real-world applications of AI that are reshaping       │
# │  patient care.', 'position': 2}, {'title': '7 ways AI is transforming healthcare', 'link':                      │
# │  'https://www.weforum.org/stories/2025/08/ai-transforming-global-health/', 'snippet': 'Medical and healthcare   │
# │  - annual private investment in AI · AI can interpret brain scans · AI can spot more bone fractures than        │
# │  humans can.', 'position': 3}, {'title': 'Health Care AI', 'link':                                              │
# │  'https://www.ama-assn.org/topics/health-care-ai', 'snippet': 'Stay up-to-date on information about trends in   │
# │  healthcare and AI, including the latest ai healthcare news and AMA statements and policies.', 'position': 4},  │
# │  {'title': 'AI in Medicine', 'link': 'https://www.nejm.org/ai-in-medicine', 'snippet': 'AI in Medicine          │
# │  explores the history and vast potential of artificial intelligence and machine learning across all areas of    │
# │  health care.', 'position': 5}, {'title': 'How AI is transforming medicine', 'link':                            │
# │  'https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/', 'snippet':       │
# │  'Experts predict that the adoption of large language models will reshape medicine. Some compare the potential  │
# │  impact with the decoding of the human genome.', 'position': 6}, {'title': 'Artificial Intelligence in          │
# │  healthcare - Public Health - European ...', 'link': 'https://health.ec.europ...                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Satish\AgenticAI2.0\AgenticAI\my-crewai-venv\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Thought: Thought: The initial search provided a good overview of recent developments and news. I've            │
# │  identified several key areas: EHR improvements, diagnostic tools (brain scans, bone fractures),                │
# │  administrative tasks, and the potential impact of large language models. To build a comprehensive report, I    │
# │  need to delve deeper into each of these categories, gather more specific examples, and look for expert         │
# │  opinions, statistical data, and market insights. I'll start by focusing on key industry trends and             │
# │  innovations, as requested.                                                                                     │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"AI in healthcare key industry trends and innovations\"}"                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'AI in healthcare key industry trends and innovations', 'type': 'search', 'num':    │
# │  10, 'engine': 'google'}, 'organic': [{'title': 'An Overview of 2025 AI Trends in Healthcare', 'link':          │
# │  'https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare', 'snippet': 'Ambient       │
# │  Listening Reduces Clinical Documentation · Pushing for Increased Accuracy and Transparency in Generative AI ·  │
# │  Machine Vision Improves ...', 'position': 1}, {'title': 'Generative AI in healthcare: Current trends and       │
# │  future outlook', 'link':                                                                                       │
# │  'https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-f  │
# │  uture-outlook', 'snippet': 'The healthcare sector has been integrating generative AI to enhance operations     │
# │  and engage stakeholders, with many advancing to full-scale implementation.', 'position': 2}, {'title':         │
# │  'Artificial intelligence in medicine: current trends and future ...', 'link':                                  │
# │  'https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/', 'snippet': 'by VH Buch · 2018 · Cited by 579 — WHAT ARE   │
# │  THE CURRENT TRENDS IN MEDICAL AI? · AI excels at well-defined tasks · AI is supporting doctors, not replacing  │
# │  them · AI supports poorly resourced services.', 'position': 3}, {'title': 'How Emerging Trends in AI Are       │
# │  Shaping the Future of ...', 'link':                                                                            │
# │  'https://learn.hms.harvard.edu/insights/all-insights/how-emerging-trends-ai-are-shaping-future-health-care-qu  │
# │  ality-and-safety', 'snippet': 'The next big technology to revolutionize health care will be artificial         │
# │  intelligence (AI). “Health care professionals should get very interested in AI and ...', 'position': 4},       │
# │  {'title': '7 ways AI is transforming healthcare', 'link':                                                      │
# │  'https://www.weforum.org/stories/2025/08/ai-transforming-global-health/', 'snippet': 'AI technologies are      │
# │  already helping doctors spot fractures, triage patients and detect early signs of disease. Yet healthcare is   │
# │  "below average" ...', 'position': 5}, {'title': 'AI in Healthcare: Key Use Cases, Challenges, a...             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Satish\AgenticAI2.0\AgenticAI\my-crewai-venv\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Thought: Thought: I have gathered information on recent developments and key industry trends. The themes       │
# │  emerging are:                                                                                                  │
# │  *   **Generative AI & LLMs:** Transforming operations, stakeholder engagement, clinical documentation          │
# │  (ambient listening/scribes), and potentially reshaping medicine.                                               │
# │  *   **Diagnostics:** Improved accuracy in interpreting scans (brain, CT, MR), spotting bone fractures,         │
# │  detecting early signs of disease, and personalized treatment plans.                                            │
# │  *   **Administrative Efficiency:** Managing billing, claims processing, scheduling, and reducing burdens.      │
# │  *   **Resource Allocation:** Predictive modeling for patient admissions and optimizing hospital resource use.  │
# │  *   **Personalized Medicine:** Enabling more precise, predictive, and portable healthcare.                     │
# │  *   **Support for Doctors:** AI as a tool to support, not replace, doctors, especially in poorly resourced     │
# │  services.                                                                                                      │
# │  Now I need to gather expert opinions and analyses, and then statistical data and market insights. I'll focus   │
# │  on expert opinions first.                                                                                      │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"AI in healthcare expert opinions and analyses\"}"                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'AI in healthcare expert opinions and analyses', 'type': 'search', 'num': 10,       │
# │  'engine': 'google'}, 'organic': [{'title': 'Artificial intelligence in healthcare: transforming the ...',      │
# │  'link': 'https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/', 'snippet': 'by J Bajwa · 2021 · Cited by 1418 —   │
# │  In this review article, we outline recent breakthroughs in the application of AI in healthcare, describe a     │
# │  roadmap to building effective, reliable and safe AI ...', 'position': 1}, {'title': 'Artificial Intelligence   │
# │  (AI) in Healthcare & Medical Field', 'link':                                                                   │
# │  'https://www.foreseemed.com/artificial-intelligence-in-healthcare', 'snippet': 'One of the greatest strengths  │
# │  of AI in healthcare is its ability to analyze vast amounts of clinical data quickly, helping professionals     │
# │  identify disease ...', 'position': 2}, {'title': '7 ways AI is transforming healthcare', 'link':               │
# │  'https://www.weforum.org/stories/2025/08/ai-transforming-global-health/', 'snippet': 'AI technologies are      │
# │  already helping doctors spot fractures, triage patients and detect early signs of disease. Yet healthcare is   │
# │  "below average" ...', 'position': 3}, {'title': 'Big majority of doctors see upsides to using health care      │
# │  AI', 'link':                                                                                                   │
# │  'https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using-health-ca  │
# │  re-ai', 'snippet': 'Also, 56% of respondents thought AI would be helpful in improving care coordination,       │
# │  patient convenience and patient safety. However, 39% were ...', 'position': 4}, {'title': 'Benefits and Risks  │
# │  of AI in Health Care: Narrative Review', 'link': 'https://www.i-jmr.org/2024/1/e53616', 'snippet': 'by M       │
# │  Chustecki · 2024 · Cited by 56 — AI technologies can alleviate the burden on health care workers by assisting  │
# │  with administrative tasks, data analysis, and image interpretation.', 'position': 5}, {'title': 'Artificial    │
# │  Intelligence and Decision-Making in Healthcare', 'link':                                                       │
# │  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/', 'snippet':...                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Satish\AgenticAI2.0\AgenticAI\my-crewai-venv\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Thought: Thought: I have gathered information on recent developments, industry trends, and expert opinions.    │
# │  Key expert opinions highlight AI's ability to analyze vast amounts of data, assist with diagnostics and        │
# │  treatment planning, alleviate administrative burden, and improve care coordination. However, there's also a    │
# │  noted distrust among patients regarding AI in their own healthcare, and some concerns about safety and         │
# │  transparency.                                                                                                  │
# │  Now, I need to focus on statistical data and market insights to complete the research.                         │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"AI in healthcare market size and growth statistics\"}"                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'AI in healthcare market size and growth statistics', 'type': 'search', 'num': 10,  │
# │  'engine': 'google'}, 'organic': [{'title': 'AI In Healthcare Market Size, Share | Industry Report, 2030',      │
# │  'link': 'https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market',    │
# │  'snippet': 'The AI in healthcare market was USD 26.57 billion in 2024, projected to reach USD 187.69 billion   │
# │  by 2030, with a 38.62% CAGR. North America dominated in 2024.', 'position': 1}, {'title': "AI's US$ 868        │
# │  billion healthcare revolution | Strategy&", 'link':                                                            │
# │  'https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.html',         │
# │  'snippet': 'Currently, the share of the healthcare market addressed through AI accounts for less than 15% of   │
# │  the global healthcare market, but it is projected to exceed 30% ...', 'position': 2}, {'title': 'Artificial    │
# │  Intelligence (AI) in Healthcare Market', 'link':                                                               │
# │  'https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-healthcare-market-54679303.html',    │
# │  'snippet': 'Global Artificial Intelligence (AI) in healthcare market valued at $14.92B in 2024, reached        │
# │  $21.66B in 2025, and is projected to grow at a robust 38.6% CAGR ...', 'position': 3}, {'title': 'AI in        │
# │  Healthcare Market Size, Share | Growth Report [2025- ...', 'link':                                             │
# │  'https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-market-100534  │
# │  ', 'snippet': 'The global AI in healthcare market size was valued at $29.01 billion in 2024 & is projected to  │
# │  grow from $39.25 billion in 2025 to $504.17 billion by 2032.', 'position': 4}, {'title': 'AI in Healthcare     │
# │  Market Leads 37.66% Healthy CAGR ...', 'link':                                                                 │
# │  'https://www.towardshealthcare.com/insights/ai-in-healthcare-market', 'snippet': 'The AI in healthcare market  │
# │  is anticipated to grow from USD 27.59 billion in 2024 to USD 674.19 billion by 2034, achieving a CAGR of       │
# │  37.66%.', 'position': 5}, {'title': 'Artificial Intelligence (AI) in...                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # AI in Healthcare: Comprehensive Research Brief                                                               │
# │                                                                                                                 │
# │  ## Executive Summary                                                                                           │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) is rapidly transforming the healthcare sector, ushering in a new era of           │
# │  efficiency, diagnostic accuracy, and personalized patient care. Recent developments highlight the integration  │
# │  of AI across various facets, from enhancing electronic health records (EHR) and streamlining administrative    │
# │  tasks to revolutionizing diagnostic capabilities and facilitating drug discovery. The market for AI in         │
# │  healthcare is experiencing explosive growth, projected to reach hundreds of billions of dollars by the early   │
# │  2030s, driven by continuous innovation and increasing adoption. While experts widely acknowledge the immense   │
# │  potential of AI to alleviate clinician burden, improve patient outcomes, and optimize resource allocation,     │
# │  concerns regarding data privacy, ethical deployment, and patient trust remain critical considerations for its  │
# │  widespread and responsible integration.                                                                        │
# │                                                                                                                 │
# │  ## Comprehensive Analysis of Current Trends and Developments                                                   │
# │                                                                                                                 │
# │  ### 1. Recent Developments and News                                                                            │
# │                                                                                                                 │
# │  *   **Enhanced Electronic Health Records (EHR) and Documentation:** AI-powered tools are improving the         │
# │  precision of EHR notes by automatically capturing procedure details, appropriate codes, and clinical           │
# │  justifications. This includes the adoption of AI scribes that record patient-provider conversations and draft  │
# │  clinical documentation, significantly reducing administrative burden for healthcare professionals.             │
# │      *   *Source:* [Healthcare IT News](https://www.healthcareitnews.com/topics/artificial-intelligence),       │
# │  [BioPharmaDive](https://www.biopharmadive.com/news/healthcare-ai-artificial-intelligence-digital-divide-safet  │
# │  y-net-providers/801912/)                                                                                       │
# │  *   **Revolutionary Diagnostic Tools:** AI is demonstrating superior capabilities in interpreting complex      │
# │  medical images and identifying conditions.                                                                     │
# │      *   AI can interpret brain scans with high accuracy.                                                       │
# │      *   AI can spot more bone fractures than humans can, aiding in faster and more accurate diagnoses.         │
# │      *   AI is being used to detect early signs of diseases.                                                    │
# │      *   *Source:* [World Economic                                                                              │
# │  Forum](https://www.weforum.org/stories/2025/08/ai-transforming-global-health/)                                 │
# │  *   **Administrative Efficiencies:** Nearly half of U.S. hospitals are leveraging AI tools for managing        │
# │  billing, claims processing, and scheduling, which directly contributes to reducing administrative burdens.     │
# │      *   *Source:* [Bipartisan Policy                                                                           │
# │  Center](https://bipartisanpolicy.org/explainer/ai-in-health-care-five-key-developments/)                       │
# │  *   **Emergence of Large Language Models (LLMs):** Experts predict that the adoption of large language models  │
# │  will profoundly reshape medicine, with some comparing its potential impact to that of decoding the human       │
# │  genome. Generative AI is being integrated to enhance operations and engage stakeholders, moving towards        │
# │  full-scale implementation.                                                                                     │
# │      *   *Source:* [Harvard                                                                                     │
# │  Gazette](https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/),          │
# │  [McKinsey &                                                                                                    │
# │  Company](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-tren  │
# │  ds-and-future-outlook)                                                                                         │
# │  *   **Optimizing Resource Allocation:** Predictive modeling facilitated by AI can forecast patient admissions  │
# │  and optimize the use of hospital resources, leading to more efficient healthcare delivery.                     │
# │      *   *Source:* [European                                                                                    │
# │  Commission](https://health.ec.europa.eu/ehealth-digital-health-and-care/artificial-intelligence-healthcare_en  │
# │  )                                                                                                              │
# │                                                                                                                 │
# │  ### 2. Key Industry Trends and Innovations                                                                     │
# │                                                                                                                 │
# │  *   **Generative AI and Ambient Listening:** A significant trend is the rise of generative AI, particularly    │
# │  in areas like ambient listening, which reduces clinical documentation burden by automatically transcribing     │
# │  and summarizing patient encounters. This enhances efficiency and allows clinicians to focus more on patient    │
# │  interaction.                                                                                                   │
# │      *   *Source:* [HealthTech                                                                                  │
# │  Magazine](https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare), [McKinsey &      │
# │  Company](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-tren  │
# │  ds-and-future-outlook)                                                                                         │
# │  *   **Precision in Diagnostics and Treatment:** AI is enhancing the accuracy and efficiency of diagnostics by  │
# │  streamlining workflows, improving precision in CT imaging, and accelerating MR image interpretation. This      │
# │  leads to more accurate diagnoses and personalized treatment plans.                                             │
# │      *   *Source:*                                                                                              │
# │  [Cprime](https://www.cprime.com/resources/blog/the-future-of-ai-in-healthcare-trends-and-innovations/),        │
# │  [Invensis](https://www.invensis.net/blog/ai-in-healthcare)                                                     │
# │  *   **Machine Vision Improvements:** Machine vision technologies are improving in areas such as identifying    │
# │  more bone fractures than humans and triaging patients effectively.                                             │
# │      *   *Source:* [HealthTech                                                                                  │
# │  Magazine](https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare), [World Economic  │
# │  Forum](https://www.weforum.org/stories/2025/08/ai-transforming-global-health/)                                 │
# │  *   **Personalized, Predictive, and Portable Healthcare:** Advances in AI are paving the way for a future      │
# │  where healthcare is more personalized, precise, predictive, and portable, allowing for tailored interventions  │
# │  and proactive health management.                                                                               │
# │      *   *Source:* [PMC (J Bajwa, 2021)](https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/)                     │
# │  *   **AI as a Support Tool for Clinicians:** AI is increasingly seen as a tool to support doctors rather than  │
# │  replace them, excelling at well-defined tasks and supporting poorly resourced services. It allows physicians   │
# │  to make more accurate diagnoses and streamline operations.                                                     │
# │      *   *Source:* [PMC (V H Buch, 2018)](https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/), [Definitive       │
# │  Healthcare](https://www.definitivehc.com/blog/6-ways-ai-is-transforming-healthcare)                            │
# │                                                                                                                 │
# │  ### 3. Expert Opinions and Analyses                                                                            │
# │                                                                                                                 │
# │  *   **Data Analysis Prowess:** Experts emphasize AI's greatest strength: its ability to analyze vast amounts   │
# │  of clinical data quickly, helping professionals identify diseases, predict outcomes, and manage population     │
# │  health more effectively.                                                                                       │
# │      *   *Source:* [Foreseemed](https://www.foreseemed.com/artificial-intelligence-in-healthcare), [PMC (M      │
# │  Khosravi, 2024)](https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/)                                           │
# │  *   **Alleviating Workload and Improving Care:** AI technologies can significantly alleviate the burden on     │
# │  healthcare workers by assisting with administrative tasks, data analysis, and image interpretation. A large    │
# │  majority of doctors (56% of respondents in one survey) see AI as helpful in improving care coordination,       │
# │  patient convenience, and patient safety.                                                                       │
# │      *   *Source:* [I-JMR (M Chustecki, 2024)](https://www.i-jmr.org/2024/1/e53616),                            │
# │  [AMA-Assn](https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using  │
# │  -health-care-ai)                                                                                               │
# │  *   **Roadmap for Effective AI:** There's a recognized need for a roadmap to building effective, reliable,     │
# │  and safe AI in healthcare, highlighting the importance of robust development and deployment strategies.        │
# │      *   *Source:* [PMC (J Bajwa, 2021)](https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/)                     │
# │  *   **Patient Distrust and Comfort Levels:** Despite the potential advantages, patients generally exhibit      │
# │  distrust of AI in healthcare. A Pew Research Center study in 2023 found that 60% of Americans would be         │
# │  uncomfortable with their provider relying on AI for their own health care, with only 46% of men comfortable    │
# │  with AI diagnosing disease and recommending treatment.                                                         │
# │      *   *Source:* [Blood Cancer                                                                                │
# │  United](https://bloodcancerunited.org/resources/blog/how-patients-really-feel-about-artificial-intelligence-h  │
# │  ealthcare), [Pew Research                                                                                      │
# │  Center](https://www.pewresearch.org/science/2023/02/22/60-of-americans-would-be-uncomfortable-with-provider-r  │
# │  elying-on-ai-in-their-own-health-care/)                                                                        │
# │  *   **Ethical Considerations:** As AI integration deepens, discussions around ethical implications,            │
# │  transparency, and accountability are becoming increasingly vital.                                              │
# │                                                                                                                 │
# │  ## Verified Facts and Statistics                                                                               │
# │                                                                                                                 │
# │  ### Market Size and Growth Projections                                                                         │
# │                                                                                                                 │
# │  The AI in healthcare market is experiencing substantial growth, with various research firms providing          │
# │  consistent projections:                                                                                        │
# │                                                                                                                 │
# │  *   **Grand View Research:** Valued the AI in healthcare market at **USD 26.57 billion in 2024**, projected    │
# │  to reach **USD 187.69 billion by 2030**, exhibiting a **Compound Annual Growth Rate (CAGR) of 38.62%**. North  │
# │  America dominated the market in 2024.                                                                          │
# │      *   *Source:* [Grand View                                                                                  │
# │  Research](https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market)    │
# │  *   **Fortune Business Insights:** Estimated the global AI in healthcare market size at **USD 29.01 billion    │
# │  in 2024**, expected to grow from **USD 39.25 billion in 2025 to USD 504.17 billion by 2032**.                  │
# │      *   *Source:* [Fortune Business                                                                            │
# │  Insights](https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-mark  │
# │  et-100534)                                                                                                     │
# │  *   **MarketsandMarkets:** Valued the market at **$14.92 billion in 2024**, reaching **$21.66 billion in       │
# │  2025**, and projected to grow at a robust **38.6% CAGR**.                                                      │
# │      *   *Source:*                                                                                              │
# │  [MarketsandMarkets](https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-healthcare-marke  │
# │  t-54679303.html)                                                                                               │
# │  *   **Towards Healthcare:** Anticipates the AI in healthcare market to grow from **USD 27.59 billion in 2024   │
# │  to USD 674.19 billion by 2034**, achieving a CAGR of **37.66%**.                                               │
# │      *   *Source:* [Towards Healthcare](https://www.towardshealthcare.com/insights/ai-in-healthcare-market)     │
# │  *   **Precedence Research:** Reports the global AI in healthcare market size reached **USD 26.69 billion in    │
# │  2024** and is projected to hit around **USD 613.81 billion by 2034**.                                          │
# │      *   *Source:* [Precedence                                                                                  │
# │  Research](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market)                     │
# │  *   **PwC Strategy&:** While the healthcare market addressed by AI accounts for less than 15% of the global    │
# │  healthcare market currently, it is projected to exceed 30%.                                                    │
# │      *   *Source:* [PwC                                                                                         │
# │  Strategy&](https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.htm  │
# │  l)                                                                                                             │
# │                                                                                                                 │
# │  These consistent projections underscore a strong market confidence and significant investment in AI            │
# │  healthcare solutions over the next decade.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1b42dad7-b006-4684-adec-50b0295fc08b                                                                     │
# │  Agent: Senior Research Analyst                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │              Using the research brief provided, create an engaging blog post that:                              │
# │              1. Transforms technical information into accessible content                                        │
# │              2. Maintains all factual accuracy and citations from the research                                  │
# │              3. Includes:                                                                                       │
# │                  - Attention-grabbing introduction                                                              │
# │                  - Well-structured body sections with clear headings                                            │
# │                  - Compelling conclusion                                                                        │
# │              4. Preserves all source citations in [Source: URL] format                                          │
# │              5. Includes a References section at the end                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by
# ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CD19272850>, 'Connection to
# telemetry.crewai.com timed out. (connect timeout=29.99999499320984)'))
# ...
#
# Beyond documentation, nearly half of U.S. hospitals are already leveraging AI for mundane but critical tasks like managing billing, claims processing, and scheduling, significantly contributing to reduced administrative workload [Source: https://bipartisanpolicy.org/explainer/ai-in-health-care-five-key-developments/](https://bipartisanpolicy.org/explainer/ai-in-health-care-five-key-developments/). Moreover, AI's predictive modeling capabilities can forecast patient admissions and optimize the use of hospital resources, leading to more efficient healthcare delivery overall [Source: https://health.ec.europa.eu/ehealth-digital-health-and-care/artificial-intelligence-healthcare_en](https://health.ec.europa.eu/ehealth-digital-health-and-care/artificial-intelligence-healthcare_en). The rise of generative AI, particularly in areas like ambient listening, further reduces clinical documentation burden by automatically transcribing and summarizing patient encounters, enhancing both efficiency and the quality of patient engagement [Source: https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare](https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare), [Source: https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook).
#
# ### Unlocking Diagnostic Superpowers
#
# Perhaps one of the most exciting frontiers for AI in healthcare is its revolutionary impact on diagnostics. AI is demonstrating superior capabilities in interpreting complex medical images and identifying conditions that might elude the human eye. It can interpret brain scans with remarkable accuracy, spot more bone fractures than humans, and is being utilized to detect early signs of diseases, leading to faster and more accurate diagnoses [Source: https://www.weforum.org/stories/2025/08/ai-transforming-global-health/](https://www.weforum.org/stories/2025/08/ai-transforming-global-health/).
#
# AI is enhancing the accuracy and efficiency of diagnostics by streamlining workflows, improving precision in CT imaging, and accelerating MR image interpretation. This directly translates into more accurate diagnoses and the foundation for truly personalized treatment plans [Source: https://www.cprime.com/resources/blog/the-future-of-ai-in-healthcare-trends-and-innovations/](https://www.cprime.com/resources/blog/the-future-of-ai-in-healthcare-trends-and-innovations/), [Source: https://www.invensis.net/blog/ai-in-healthcare](https://www.invensis.net/blog/ai-in-healthcare). Machine vision technologies continue to improve, further bolstering abilities in areas like identifying subtle abnormalities and effectively triaging patients [Source: https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare](https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare).
#
# ### The Future is Personal (and Predictive!)
#
# The emergence of Large Language Models (LLMs) is predicted to profoundly reshape medicine, with some experts comparing its potential impact to that of decoding the human genome [Source: https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/](https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/). Generative AI is being integrated to enhance operations and engage stakeholders, moving towards full-scale implementation across healthcare [Source: https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook).
#
# Advances in AI are paving the way for a future where healthcare is more personalized, precise, predictive, and portable, allowing for tailored interventions and proactive health management unique to each individual [Source: https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/](https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/). Critically, AI is increasingly seen as a powerful tool to *support* doctors, not replace them. It excels at well-defined tasks, supports poorly resourced services, and empowers physicians to make more accurate diagnoses and streamline operations, ultimately enhancing their capabilities rather than diminishing their role [Source: https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/](https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/), [Source: https://www.definitivehc.com/blog/6-ways-ai-is-transforming-healthcare](https://www.definitivehc.com/blog/6-ways-ai-is-transforming-healthcare).
#
# ### Navigating the Ethical Frontier and Building Trust
#
# While the potential benefits are immense, the integration of AI into healthcare is not without its challenges. Experts highlight AI's greatest strength as its ability to analyze vast amounts of clinical data quickly, aiding professionals in identifying diseases, predicting outcomes, and managing population health more effectively [Source: https://www.foreseemed.com/artificial-intelligence-in-healthcare](https://www.foreseemed.com/artificial-intelligence-in-healthcare), [Source: https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/](https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/). Furthermore, AI technologies can significantly alleviate the burden on healthcare workers, with a large majority of doctors (56% in one survey) recognizing AI's potential to improve care coordination, patient convenience, and safety [Source: https://www.i-jmr.org/2024/1/e53616](https://www.i-jmr.org/2024/1/e53616), [Source: https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using-health-care-ai](https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using-health-care-ai).
#
# However, patient comfort levels remain a critical factor. A 2023 Pew Research Center study revealed that 60% of Americans would be uncomfortable with their provider relying on AI for their own healthcare, and only 46% of men felt comfortable with AI diagnosing disease and recommending treatment [Source: https://bloodcancerunited.org/resources/blog/how-patients-really-feel-about-artificial-intelligence-healthcare](https://bloodcancerunited.org/resources/blog/how-patients-really-feel-about-artificial-intelligence-healthcare), [Source: https://www.pewresearch.org/science/2023/02/22/60-of-americans-would-be-uncomfortable-with-provider-relying-on-ai-in-their-own-health-care/](https://www.pewresearch.org/science/2023/02/22/60-of-americans-would-be-uncomfortable-with-provider-relying-on-ai-in-their-own-health-care/). This highlights the crucial need for transparent, ethical, and accountable AI development and deployment strategies. Experts emphasize the importance of a clear roadmap to building effective, reliable, and safe AI in healthcare to foster trust and ensure responsible integration [Source: https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/](https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/).
#
# ### The Booming Business of Healing: AI's Explosive Market Growth
#
# The financial landscape of AI in healthcare mirrors its transformative potential, with market projections showing explosive growth. The AI in healthcare market was valued at approximately **USD 26-29 billion in 2024** by various research firms and is consistently projected to reach hundreds of billions of dollars by the early 2030s.
#
# For instance:
# *   **Grand View Research** valued the market at **USD 26.57 billion in 2024**, projecting it to hit **USD 187.69 billion by 2030** with a **CAGR of 38.62%** [Source: https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market](https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market).
# *   **Fortune Business Insights** estimated the market at **USD 29.01 billion in 2024**, anticipating growth to **USD 504.17 billion by 2032** [Source: https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-market-100534](https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-market-100534).
# *   **MarketsandMarkets** reported a market value of **$14.92 billion in 2024**, growing at a robust **38.6% CAGR** [Source: https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-healthcare-market-54679303.html](https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-in-healthcare-market-54679303.html).
# *   **Towards Healthcare** predicts growth from **USD 27.59 billion in 2024 to USD 674.19 billion by 2034**, with a CAGR of **37.66%** [Source: https://www.towardshealthcare.com/insights/ai-in-healthcare-market](https://www.towardshealthcare.com/insights/ai-in-healthcare-market).
# *   **Precedence Research** aligns with these trends, projecting the market to reach around **USD 613.81 billion by 2034** from **USD 26.69 billion in 2024** [Source: https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market).
#
# These consistent projections underscore strong market confidence and significant investment, with North America leading the market in 2024. PwC Strategy& even anticipates that the healthcare market addressed by AI, currently less than 15% of the global healthcare market, is projected to exceed 30% [Source: https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.html](https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.html).
#
# ### The Future of Health is Now
#
# AI is undeniably transforming healthcare, moving beyond theoretical discussions to tangible applications that enhance efficiency, improve diagnostic accuracy, and pave the way for highly personalized patient care. While the journey requires careful navigation of ethical considerations, data privacy, and building patient trust, the immense potential to alleviate clinician burden and optimize resource allocation makes it a pivotal advancement. As experts continue to develop robust and safe AI solutions, we are stepping into an era where technology becomes a powerful ally, helping us build a healthier, more efficient, and more personalized healthcare system for all.
#
# ---
#
# ### References
#
# *   [https://www.healthcareitnews.com/topics/artificial-intelligence](https://www.healthcareitnews.com/topics/artificial-intelligence)
# *   [https://www.biopharmadive.com/news/healthcare-ai-artificial-intelligence-digital-divide-safety-net-providers/801912/](https://www.biopharmadive.com/news/healthcare-ai-artificial-intelligence-digital-divide-safety-net-providers/801912/)
# *   [https://www.weforum.org/stories/2025/08/ai-transforming-global-health/](https://www.weforum.org/stories/2025/08/ai-transforming-global-health/)
# *   [https://bipartisanpolicy.org/explainer/ai-in-health-care-five-key-developments/](https://bipartisanpolicy.org/explainer/ai-in-health-care-five-key-developments/)
# *   [https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/](https://news.harvard.edu/gazette/story/2025/03/how-ai-is-transforming-medicine-healthcare/)
# *   [https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-current-trends-and-future-outlook)
# *   [https://health.ec.europa.eu/ehealth-digital-health-and-care/artificial-intelligence-healthcare_en](https://health.ec.europa.eu/ehealth-digital-health-and-care/artificial-intelligence-healthcare_en)
# *   [https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare](https://healthtechmagazine.net/article/2025/01/overview-2025-ai-trends-healthcare)
# *   [https://www.cprime.com/resources/blog/the-future-of-ai-in-healthcare-trends-and-innovations/](https://www.cprime.com/resources/blog/the-future-of-ai-in-healthcare-trends-and-innovations/)
# *   [https://www.invensis.net/blog/ai-in-healthcare](https://www.invensis.net/blog/ai-in-healthcare)
# *   [https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/](https://pmc.ncbi.nlm.nih.gov/articles/PMC8285156/)
# *   [https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/](https://pmc.ncbi.nlm.nih.gov/articles/PMC5819974/)
# *   [https://www.definitivehc.com/blog/6-ways-ai-is-transforming-healthcare](https://www.definitivehc.com/blog/6-ways-ai-is-transforming-healthcare)
# *   [https://www.foreseemed.com/artificial-intelligence-in-healthcare](https://www.foreseemed.com/artificial-intelligence-in-healthcare)
# *   [https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/](https://pmc.ncbi.nlm.nih.gov/articles/PMC10916499/)
# *   [https://www.i-jmr.org/2024/1/e53616](https://www.i-jmr.org/2024/1/e53616)
# *   [https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using-health-care-ai](https://www.ama-assn.org/practice-management/digital-health/big-majority-doctors-see-upsides-using-health-care-ai)
# *   [https://bloodcancerunited.org/resources/blog/how-patients-really-feel-about-artificial-intelligence-healthcare](https://bloodcancerunited.org/resources/blog/how-patients-really-feel-about-artificial-intelligence-healthcare)
# *   [https://www.pewresearch.org/science/2023/02/22/60-of-americans-would-be-uncomfortable-with-provider-relying-on-ai-in-their-own-health-care/](https://www.pewresearch.org/science/2023/02/22/60-of-americans-would-be-uncomfortable-with-provider-relying-on-ai-in-their-own-health-care/)
# *   [https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market](https://www.grandviewresearch.com/industry-analysis/artificial-intelligence-ai-healthcare-market)
# *   [https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-market-100534](https://www.fortunebusinessinsights.com/industry-reports/artificial-intelligence-in-healthcare-market-100534)
# *   [https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-healthcare-market-54679303.html](https://www.marketsandmarkets.com/Market-Reports/artificial-intelligence-healthcare-market-54679303.html)
# *   [https://www.towardshealthcare.com/insights/ai-in-healthcare-market](https://www.towardshealthcare.com/insights/ai-in-healthcare-market)
# *   [https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market)
# *   [https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.html](https://www.strategyand.pwc.com/de/en/industries/pharma-life-sciences/ai-healthcare-revolution.html)
# ```
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CD19272AD0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.99999189376831)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CD19272850>, 'Connection to telemetry.crewai.com timed out. (connect timeout=29.999996662139893)'))

# %% [markdown]
# ---
