# %% [markdown]
# <hr>
#
# # MCP in AutoGen
# <hr>

# %% [markdown]
# #### Reference URL
#
# https://microsoft.github.io/autogen/stable//user-guide/core-user-guide/components/workbench.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Reference
# https://microsoft.github.io/autogen/stable//reference/python/autogen_ext.tools.mcp.html#autogen_ext.tools.mcp.McpWorkbench <br>
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### StdioServerParams
#
# ##### Reference
#
# https://microsoft.github.io/autogen/stable//reference/python/autogen_ext.tools.mcp.html#autogen_ext.tools.mcp.StdioServerParams
# <br>
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Show JSON Schema of StdioServerParams

# %%
{
   "title": "StdioServerParams",
   "description": "Parameters for connecting to an MCP server over STDIO.",
   "type": "object",
   "properties": {
      "command": {
         "title": "Command",
         "type": "string"
      },
      "args": {
         "items": {
            "type": "string"
         },
         "title": "Args",
         "type": "array"
      },
      "env": {
         "anyOf": [
            {
               "additionalProperties": {
                  "type": "string"
               },
               "type": "object"
            },
            {
               "type": "null"
            }
         ],
         "default": null,
         "title": "Env"
      },
      "cwd": {
         "anyOf": [
            {
               "type": "string"
            },
            {
               "format": "path",
               "type": "string"
            },
            {
               "type": "null"
            }
         ],
         "default": null,
         "title": "Cwd"
      },
      "encoding": {
         "default": "utf-8",
         "title": "Encoding",
         "type": "string"
      },
      "encoding_error_handler": {
         "default": "strict",
         "enum": [
            "strict",
            "ignore",
            "replace"
         ],
         "title": "Encoding Error Handler",
         "type": "string"
      },
      "type": {
         "const": "StdioServerParams",
         "default": "StdioServerParams",
         "title": "Type",
         "type": "string"
      },
      "read_timeout_seconds": {
         "default": 5,
         "title": "Read Timeout Seconds",
         "type": "number"
      }
   },
   "required": [
      "command"
   ]
}

# %% [markdown]
# #### StreamableHttpServerParams

# %% [markdown]
# #### Reference
#
# https://microsoft.github.io/autogen/stable//reference/python/autogen_ext.tools.mcp.html#autogen_ext.tools.mcp.StreamableHttpServerParams
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### autogen_ext.tools.http
#
# ##### Reference
#
# https://microsoft.github.io/autogen/stable//reference/python/autogen_ext.tools.http.html <br>
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Time MCP Server
#
# https://github.com/modelcontextprotocol/servers/tree/main/src/time
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png)
#
# `Using uvx`
#
# ```Json
# {
#   "mcp": {
#     "servers": {
#       "time": {
#         "command": "uvx",
#         "args": ["mcp-server-time"]
#       }
#     }
#   }
# }

# %% [markdown]
# ![image.png](attachment:image.png)
#
# `Example`
# ```Json
# {
#   "command": "python",
#   "args": ["-m", "mcp_server_time", "--local-timezone=America/New_York"]
# }

# %% [markdown]
# <hr>
#
# ## MCP (Model Context Protocol)
# <hr>

# %% [markdown]
# #### Reference
#
# https://modelcontextprotocol.io/overview
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png) <br>
#
# ![image-4.png](attachment:image-4.png) <br>
#
# ![image-5.png](attachment:image-5.png) <br>
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# <hr>
#
# # MCP Server
# <hr>

# %% [markdown]
# #### References
#
# https://mcpservers.org/ <br>
#
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png) <br>
#
# ![image-4.png](attachment:image-4.png) <br>
#
# ![image-5.png](attachment:image-5.png) <br>
#
# ![image-6.png](attachment:image-6.png) <br> <br> <br>
#
# ![image-7.png](attachment:image-7.png)
