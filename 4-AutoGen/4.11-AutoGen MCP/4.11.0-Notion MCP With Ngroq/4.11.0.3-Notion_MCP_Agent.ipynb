# %% [markdown]
# <hr>
#
# ### `Notion MCP`
# <hr>
#
# `Notion MCP` is our hosted server that gives **AI tools** secure access to your Notion workspace. It's designed to work seamlessly with popular AI assistants like **ChatGPT, Cursor, and Claude**.
#
# <hr>
#
# ##### References
#
# https://developers.notion.com/docs/mcp

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Developer Notion
#
#
# ##### References
# https://developers.notion.com/
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### `Class Notes`
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# <hr>
#
# ### Notion MCP Server
# <hr>
#
# #### References
# https://github.com/makenotion/notion-mcp-server
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# **Go to** https://www.notion.so/profile/integrations
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# <hr>
#
# ### `MCP Google Map Server`
# <hr>
#
# A powerful `Model Context Protocol (MCP)` server providing comprehensive **Google Maps API** integration with streamable `HTTP` transport support and LLM processing capabilities.
#
# <hr>
#
# ##### References
#
# https://github.com/cablate/mcp-google-map

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr>
#
# ### `Cat Fact API`
# <hr>
#
# ##### References
# https://catfact.ninja/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr>
#
# ### `Ngrok`
# <hr>
#
# `Ngrok` is a tool that creates **a secure tunnel from the public internet to your local machine**, making it easy to **expose local servers** (like your Streamlit, Flask, or FastAPI apps) to the outside world.
#
# <hr>
#
# ##### References
#
# https://ngrok.com/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# <hr>
#
# ### `Lovable`
# <hr>
#
# `Lovable` is a platform where you describe an app or website in plain English, and the AI builds it - **frontend, backend, database, authentication,** even **payment integration** - without writing a single line of boilerplate code.
#
# Originally based on GPT‑Engineer, it's evolved into a full product that supports collaboration (multiplayer/teamwork), a chat-powered code assistant, visual editing, and built‑in deployment workflows
#
# <hr>
#
# ##### References
#
# https://lovable.dev/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr>
#
# ### `Cross-Origin Resource Sharing (CORS)`
# <hr>
#
# `CORS`, or **Cross-Origin Resource Sharing**, is a security feature implemented by web browsers that controls access to resources on different domains (origins). It allows a web page to request resources from a server on a different domain, but only if the server explicitly allows it through HTTP headers. This mechanism helps prevent malicious websites from accessing sensitive data from other sites without permission.
# <hr>
#
# ##### References
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Guides/CORS
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
