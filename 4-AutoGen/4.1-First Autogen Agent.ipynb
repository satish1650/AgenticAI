# %% [markdown]
# # Autogen Installation

# %% [markdown]
# 1. Create a venv
# 2. Create a requirements.txt
# 3. install autogen-agentchat autogen-core and autogen-ext

# %% [markdown]
# # First Autogen Agent

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Connecting to the Model

# %%
model_client = OpenAIChatCompletionClient(model='gpt-4o',api_key=api_key)

# %%
agent_1 = AssistantAgent(name='my_assistant',model_client=model_client)

# %%
agent_1

# %%
result = await agent_1.run(task='Tell me something about you?')

# %%
print(result)
# Out:
# messages=[TextMessage(id='a264d279-5fd0-46b1-9559-512f58874b17', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 47, 53, 815663, tzinfo=datetime.timezone.utc), content='Tell me something about you?', type='TextMessage'), TextMessage(id='91935d20-76a9-4766-ac9f-2a1e47e42102', source='my_assistant', models_usage=RequestUsage(prompt_tokens=42, completion_tokens=95), metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 47, 56, 290321, tzinfo=datetime.timezone.utc), content="I am an AI language model created by OpenAI, designed to understand and generate human-like text based on the input I receive. My purpose is to assist users by providing information, answering questions, and helping with a wide variety of topics. I can engage in conversations, offer explanations, and even provide creative content. However, I don't have personal experiences or consciousness—my responses are generated based on patterns in the data I've been trained on. Ho
# ...

# %% [markdown]
# messages=[TextMessage(id='1a65a1aa-88d7-479f-88c1-bbe27004c3e0', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 31, 54, 112126, tzinfo=datetime.timezone.utc), content='Tell me something about you?', type='TextMessage'), TextMessage(id='04fc6fd8-6cd3-45b7-9034-c913b7af6dae', source='my_assistant', models_usage=RequestUsage(prompt_tokens=42, completion_tokens=83), metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 31, 57, 124490, tzinfo=datetime.timezone.utc), content="I am a language model AI assistant, designed to understand and generate human-like text based on the input I receive. My primary function is to assist users by providing information, answering questions, and helping with a wide range of tasks, from learning and problem-solving to providing entertainment. I'm here to help you with anything you need, leveraging the vast amount of information I've been trained on. How can I assist you today?", type='TextMessage')] stop_reason=None

# %%
result2 = await agent_1.run(task='What was my last question?')

# %%
result2
# Out:
# TaskResult(messages=[TextMessage(id='a43466dd-8048-4e18-8224-03b05eb5dc6e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 32, 29, 264378, tzinfo=datetime.timezone.utc), content='What was my last question?', type='TextMessage'), TextMessage(id='da90ded9-f3b8-46a2-aa2e-6dd201e717e7', source='my_assistant', models_usage=RequestUsage(prompt_tokens=140, completion_tokens=20), metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 32, 30, 303461, tzinfo=datetime.timezone.utc), content='Your last question was, "Tell me something about you?" Would you like to ask anything else?', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=[TextMessage(id='a43466dd-8048-4e18-8224-03b05eb5dc6e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 32, 29, 264378, tzinfo=datetime.timezone.utc), content='What was my last question?', type='TextMessage'), TextMessage(id='da90ded9-f3b8-46a2-aa2e-6dd201e717e7', source='my_assistant', models_usage=RequestUsage(prompt_tokens=140, completion_tokens=20), metadata={}, created_at=datetime.datetime(2025, 7, 5, 16, 32, 30, 303461, tzinfo=datetime.timezone.utc), content='Your last question was, "Tell me something about you?" Would you like to ask anything else?', type='TextMessage')], stop_reason=None)
