# %% [markdown]
# # Langchain Tools

# %%
import os, asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from langchain_community.utilities import GoogleSerperAPIWrapper
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
serper_api_key=os.getenv("SERPER_API_KEY")
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("Please set the OPENAI_API_KEY environment variable.")

# %%
model_client= OpenAIChatCompletionClient(model="gpt-4o", api_key=api_key)

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='search')

# %%
search_tool_wrapper_response= search_tool_wrapper.run("What is autogen?")

# %%
search_tool_wrapper_response
# Out:
# 'AutoGen is an open-source programming framework for building AI agents and facilitating cooperation among multiple agents to solve tasks . AutoGen aims to provide an easy-to-use and flexible framework for accelerating development and research on agentic AI. AutoGen is an open-source framework that leverages multiple agents to enable complex workflows. This tutorial introduces basic concepts and building blocks of ... AutoGen is a framework that enables development of LLM applications using multiple agents that can converse with each other to solve tasks. AutoGen is a framework for creating multi-agent AI applications that can act autonomously or work alongside humans. Installation. AutoGen requires Python 3.10 ... AutoGen is an open-source framework designed for creating multi-agent AI applications that can operate semi-autonomously and fully autonomously. AutoGen is a multi-agent framework enabling users to define agents with unique prompts, tools, and roles to collaboratively solve complex ... A framework for building AI agents and applications Studio. An web-based UI for prototyping with agents without writing code. Built on AgentChat. pip install - ... AutoGen is a framework that helps you easily create multi-agent applications. Multi-agent applications are a relatively recent idea that involve defining ... In September 2023, we released AutoGen – a flexible and open-source Python-based framework for defining, configuring, and composing AI agents ... AutoGen is a popular framework among Python developers for building multi-agent AI systems through sophisticated, conversation-driven collaboration and human- ...'

# %%
print(search_tool_wrapper_response)
# Out:
# AutoGen is an open-source programming framework for building AI agents and facilitating cooperation among multiple agents to solve tasks . AutoGen aims to provide an easy-to-use and flexible framework for accelerating development and research on agentic AI. AutoGen is an open-source framework that leverages multiple agents to enable complex workflows. This tutorial introduces basic concepts and building blocks of ... AutoGen is a framework that enables development of LLM applications using multiple agents that can converse with each other to solve tasks. AutoGen is a framework for creating multi-agent AI applications that can act autonomously or work alongside humans. Installation. AutoGen requires Python 3.10 ... AutoGen is an open-source framework designed for creating multi-agent AI applications that can operate semi-autonomously and fully autonomously. AutoGen is a multi-agent framework enabling users to define agents with unique prompts, tools, and roles to collaboratively solve complex ... A framework for building AI agents and applications Studio. An web-based UI for prototyping with agents without writing code. Built on AgentChat. pip install - ... AutoGen is a framework that helps you easily create multi-agent applications. Multi-agent applications are a relatively recent idea that involve defining ... In September 2023, we released AutoGen – a flexible and open-source Python-based framework for defining, configuring, and composing AI agents ... AutoGen is a popular framework among Python developers for building multi-agent AI systems through sophisticated, conversation-driven collaboration and human- ...

# %%
AutoGen is an open-source programming framework for building AI agents and facilitating cooperation among multiple agents to solve tasks . AutoGen aims to provide an easy-to-use and flexible framework for accelerating development and research on agentic AI. AutoGen is an open-source framework that leverages multiple agents to enable complex workflows. This tutorial introduces basic concepts and building blocks of ... AutoGen is a framework that enables development of LLM applications using multiple agents that can converse with each other to solve tasks. AutoGen is a framework for creating multi-agent AI applications that can act autonomously or work alongside humans. Installation. AutoGen requires Python 3.10 ... AutoGen is an open-source framework designed for creating multi-agent AI applications that can operate semi-autonomously and fully autonomously. AutoGen is a multi-agent framework enabling users to define agents with unique prompts, tools, and roles to collaboratively solve complex ... A framework for building AI agents and applications Studio. An web-based UI for prototyping with agents without writing code. Built on AgentChat. pip install - ... AutoGen is a framework that helps you easily create multi-agent applications. Multi-agent applications are a relatively recent idea that involve defining ... In September 2023, we released AutoGen – a flexible and open-source Python-based framework for defining, configuring, and composing AI agents ... AutoGen is a popular framework among Python developers for building multi-agent AI systems through sophisticated, conversation-driven collaboration and human- ...

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

# %%
def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found."

# %%
search_agent= AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    # "don't send the year in query, rather use latest or recently etc.",
    reflect_on_tool_use=True,
)

# %%
async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

# %%
await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The latest Indian Premier League (IPL) champion is Royal Challengers Bengaluru (RCB), who won their first-ever IPL title recently. They claimed victory after defeating Punjab Kings by six runs in the final.

# %%
await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The winner of the IPL in 2023 was the Chennai Super Kings.

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The winner of the IPL 2025 was the Royal Challengers Bengaluru, securing their first IPL title.

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='search')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# Chennai Super Kings won the IPL 2023, defeating Gujarat Titans in the final. This victory marked their fifth IPL title.

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The winner of the IPL 2023 was the Chennai Super Kings.

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL in 2025?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL in 2025?
# The Royal Challengers Bengaluru won the IPL 2025, defeating Punjab Kings in the final to claim their maiden title.

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL recently?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL recently?
# Chennai Super Kings (CSK) won the IPL 2023 tournament.

# %% [markdown]
# Here, We have done changes in prompt and getting correct result

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool. Please make sure that you use the search_web tool to find information before you return the answer. don't send the year in query, rather use latest or recently etc.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The latest winner of the Indian Premier League (IPL) is Royal Challengers Bengaluru (RCB), who won their first-ever IPL title by defeating Punjab Kings in the final.

# %% [markdown]
# Here, We have done changes in prompt and getting correct result

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='search')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool. Please make sure that you use the search_web tool to find information before you return the answer. don't send the year in query, rather use latest or recently etc.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The latest IPL winners are Royal Challengers Bengaluru, who won the IPL 2025 title by defeating Punjab Kings in the final. This victory marked their first IPL title win.

# %% [markdown]
# Here, We have done changes in prompt and getting correct result

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='news')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool. " \
    "Please make sure that you use the search_web tool to find information before you return the answer. " \
    "don't send the year in query, rather use latest or recently etc.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The latest winner of the Indian Premier League (IPL) is the Royal Challengers Bengaluru (RCB), who won their first-ever IPL title by defeating the Punjab Kings in the 2025 final.

# %% [markdown]
# Here, We have done changes in prompt and getting correct result

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='search')

def search_web(query: str) -> str:
    """Search the web for the given query and return the results."""
    try:
        results= search_tool_wrapper.run(query)
        return results
    except Exception as ex:
        print(f"Error occurred while searching the web: {ex}")
        return "No results found." 
    
search_agent = AssistantAgent(
    name="SearchAgent",
    model_client=model_client,
    tools=[search_web],
    description="An agent that can search the web for information.",
    system_message="You are a helpful assistant that can search the web for information using the search_web tool. " \
    "Please make sure that you use the search_web tool to find information before you return the answer. " \
    "don't send the year in query, rather use latest or recently etc.",
    reflect_on_tool_use=True,
)

async def run_serper_search():
    """Run the search agent with a sample query."""
    query = "Who won the IPL?" 
    print(f"Querying: {query}")
    
    
    result = await search_agent.run(task=query)
    print(result.messages[-1].content)

await run_serper_search()
# Out:
# Querying: Who won the IPL?
# The latest IPL winner is the Royal Challengers Bengaluru, who won the 2025 season after defeating the Punjab Kings in the final. This victory marked their first IPL title.
