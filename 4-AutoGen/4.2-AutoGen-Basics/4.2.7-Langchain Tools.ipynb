# %% [markdown]
# # Langchain Tools

# %%
import os, asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from langchain_community.utilities import GoogleSerperAPIWrapper
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
# os.environ['SERPER_API_KEY']= '03efe53bf8044f01c84e9c0d43a252fc74dc64a7'
# os.environ['SERPER_API_KEY']= "b23067157b8e3607e5a89bdc75b0634750f60af2cf7d468f6370109f424998f8"
os.environ["SERPER_API_KEY"]=os.getenv("SERPER_API_KEY")
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("Please set the OPENAI_API_KEY environment variable.")

# %%
print(os.getenv("SERPER_API_KEY"))
# Out:
# b23067157b8e3607e5a89bdc75b0634750f60af2cf7d468f6370109f424998f8

# %%
model_client= OpenAIChatCompletionClient(model="gpt-4o", api_key=api_key)

# %%
search_tool_wrapper= GoogleSerperAPIWrapper(type='search')

# %%
search_tool_wrapper
# Out:
# GoogleSerperAPIWrapper(k=10, gl='us', hl='en', type='search', result_key_for_type={'news': 'news', 'places': 'places', 'images': 'images', 'search': 'organic'}, tbs=None, serper_api_key='b23067157b8e3607e5a89bdc75b0634750f60af2cf7d468f6370109f424998f8', aiosession=None)

# %% [markdown]
# GoogleSerperAPIWrapper(k=10, gl='us', hl='en', type='search', result_key_for_type={'news': 'news', 'places': 'places', 'images': 'images', 'search': 'organic'}, tbs=None, serper_api_key='b23067157b8e3607e5a89bdc75b0634750f60af2cf7d468f6370109f424998f8', aiosession=None)

# %%
search_tool_wrapper.run("What is autogen?")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 search_tool_wrapper.run("What is autogen?")
#
# File c:\Users\Satish\OneDrive\AgenticAI\AgenticAI2.0\autogen-venv\Lib\site-packages\langchain_community\utilities\google_serper.py:74, in GoogleSerperAPIWrapper.run(self, query, **kwargs)
#      72 def run(self, query: str, **kwargs: Any) -> str:
#      73     """Run query through GoogleSearch and parse result."""
# ---> 74     results = self._google_serper_api_results(
#      75         query,
#      76         gl=self.gl,
#      77         hl=self.hl,
#      78         num=self.k,
#      79         tbs=self.tbs,
#      80         search_type=self.type,
#      81         **kwargs,
#      82     )
#      84     return self._parse_results(results)
#
# ...
