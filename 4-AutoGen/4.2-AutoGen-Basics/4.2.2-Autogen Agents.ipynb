# %% [markdown]
# # Agentchat API with Assistant Agent

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")

# %%
# Define Model -> Brain

model_client= OpenAIChatCompletionClient(model="gpt-4o", api_key=api_key)

# %%
# Define Assistant -> Digital Human -> Name and Brain

my_assistant= AssistantAgent(name="Assistant", model_client=model_client)

# %%
response= my_assistant.run(task="Who are you?")

# %%
response # Not getting result because not used await here
# Out:
# <coroutine object BaseChatAgent.run at 0x000002C5233C7E00>

# %%
# run is an async method so we have to use await 

response= await my_assistant.run(task="Who are you?")

# %%
response
# Out:
# TaskResult(messages=[TextMessage(id='3b1bf696-92e9-43fc-86f6-838303c6f048', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 27, 926549, tzinfo=datetime.timezone.utc), content='Who are you?', type='TextMessage'), TextMessage(id='aecce92d-fb1b-4db5-8534-84a03273c625', source='Assistant', models_usage=RequestUsage(prompt_tokens=40, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 29, 468080, tzinfo=datetime.timezone.utc), content="I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!", type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=[TextMessage(id='3b1bf696-92e9-43fc-86f6-838303c6f048', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 27, 926549, tzinfo=datetime.timezone.utc), content='Who are you?', type='TextMessage'), TextMessage(id='aecce92d-fb1b-4db5-8534-84a03273c625', source='Assistant', models_usage=RequestUsage(prompt_tokens=40, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 29, 468080, tzinfo=datetime.timezone.utc), content="I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!", type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(
#     messages=[
#         TextMessage(id='3b1bf696-92e9-43fc-86f6-838303c6f048', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 27, 926549, tzinfo=datetime.timezone.utc), content='Who are you?', type='TextMessage'),
#
#         TextMessage(id='aecce92d-fb1b-4db5-8534-84a03273c625', source='Assistant', models_usage=RequestUsage(prompt_tokens=40, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 32, 29, 468080, tzinfo=datetime.timezone.utc), content="I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!", type='TextMessage')
#         ]
#         , stop_reason=None)

# %% [markdown]
# content="I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!"

# %%
result= await my_assistant.run(task="What was the last question I asked?")

# %%
result
# Out:
# TaskResult(messages=[TextMessage(id='9945efe2-4df7-4cab-805b-8b7c19b80627', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 30, 513297, tzinfo=datetime.timezone.utc), content='What was the last question I asked?', type='TextMessage'), TextMessage(id='9fad2ff0-ff98-42fd-b31d-4a31d73fedfb', source='Assistant', models_usage=RequestUsage(prompt_tokens=145, completion_tokens=22), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 31, 946754, tzinfo=datetime.timezone.utc), content='The last question you asked was, "Who are you?" Is there anything else I can assist you with?', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=[TextMessage(id='9945efe2-4df7-4cab-805b-8b7c19b80627', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 30, 513297, tzinfo=datetime.timezone.utc), content='What was the last question I asked?', type='TextMessage'), TextMessage(id='9fad2ff0-ff98-42fd-b31d-4a31d73fedfb', source='Assistant', models_usage=RequestUsage(prompt_tokens=145, completion_tokens=22), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 31, 946754, tzinfo=datetime.timezone.utc), content='The last question you asked was, "Who are you?" Is there anything else I can assist you with?', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(
#     messages=[
#         TextMessage(id='9945efe2-4df7-4cab-805b-8b7c19b80627', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 30, 513297, tzinfo=datetime.timezone.utc), content='What was the last question I asked?', type='TextMessage'),
#
#         TextMessage(id='9fad2ff0-ff98-42fd-b31d-4a31d73fedfb', source='Assistant', models_usage=RequestUsage(prompt_tokens=145, completion_tokens=22), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 34, 31, 946754, tzinfo=datetime.timezone.utc), content='The last question you asked was, "Who are you?" Is there anything else I can assist you with?', type='TextMessage')
#         ]
#         , stop_reason=None)

# %% [markdown]
# content='The last question you asked was, "Who are you?" Is there anything else I can assist you with?'

# %%
final_response= await my_assistant.run(task="what was the last two quesstions?")

# %%
final_response
# Out:
# TaskResult(messages=[TextMessage(id='0c58b6aa-310b-44cc-9fe5-077d9db0a732', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 35, 28, 918039, tzinfo=datetime.timezone.utc), content='what was the last two quesstions?', type='TextMessage'), TextMessage(id='9db8425e-ef83-4985-974a-5fb4ba34418c', source='Assistant', models_usage=RequestUsage(prompt_tokens=185, completion_tokens=42), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 35, 30, 105640, tzinfo=datetime.timezone.utc), content='The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(
#     messages=[TextMessage(id='0c58b6aa-310b-44cc-9fe5-077d9db0a732', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 35, 28, 918039, tzinfo=datetime.timezone.utc), content='what was the last two quesstions?', type='TextMessage'),
#
#     TextMessage(id='9db8425e-ef83-4985-974a-5fb4ba34418c', source='Assistant', models_usage=RequestUsage(prompt_tokens=185, completion_tokens=42), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 35, 30, 105640, tzinfo=datetime.timezone.utc), content='The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!', type='TextMessage')
#     ]
#     , stop_reason=None)

# %% [markdown]
# content='The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!'

# %%
final_response.messages[-1]
# Out:
# TextMessage(id='9db8425e-ef83-4985-974a-5fb4ba34418c', source='Assistant', models_usage=RequestUsage(prompt_tokens=185, completion_tokens=42), metadata={}, created_at=datetime.datetime(2025, 7, 6, 11, 35, 30, 105640, tzinfo=datetime.timezone.utc), content='The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!', type='TextMessage')

# %%
final_response.messages[-1].content
# Out:
# 'The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!'

# %%
print(final_response.messages[-1].content)
# Out:
# The last two questions you asked were:
#
# 1. "Who are you?"
# 2. "What was the last question I asked?"
#
# If you have any more questions or need further assistance, feel free to ask!

# %%
agent_state= await my_assistant.save_state()

# %%
agent_state
# Out:
# {'type': 'AssistantAgentState',
#  'version': '1.0.0',
#  'llm_context': {'messages': [{'content': 'Who are you?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "Unfortunately, I can't recall past interactions or questions unless they're part of the current session. Is there anything else you'd like to know or ask?",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
# ...

# %% [markdown]
# {'type': 'AssistantAgentState',
#  'version': '1.0.0',
#  'llm_context': {'messages': [{'content': 'Who are you?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "Unfortunately, I can't recall past interactions or questions unless they're part of the current session. Is there anything else you'd like to know or ask?",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': 'The last question you asked was, "Who are you?" Is there anything else I can assist you with?',
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'what was the last two quesstions?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': 'The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!',
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'}]}}

# %% [markdown]
# <!-- Here's The Complete State Messages's conversation, By default Maintined by Autogen  -->
#
# 'content': 'Who are you?'
#
# 'content': "I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!"
#
# 'content': 'What was the last question I asked?'
#
# 'content': "Unfortunately, I can't recall past interactions or questions unless they're part of the current session. Is there anything else you'd like to know or ask?"
#
# 'content': 'What was the last question I asked?'
#
# 'content': 'The last question you asked was, "Who are you?" Is there anything else I can assist you with?'
#
# 'content': 'what was the last two quesstions?'
#
# 'content': 'The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!'

# %% [markdown]
# # Multi Modal Capabilities:-
#
# **A multimodal large language model (MLLM)** is an AI model that integrates and processes information from multiple data modalities, such as text, images, audio, and video, to understand and generate comprehensive responses
#
#
# ![image.png](attachment:image.png)

# %%
from autogen_agentchat.messages import MultiModalMessage
from autogen_core import Image

# %%
from io import BytesIO

import PIL # Python Image Library
import requests

# %%
# Create a multi-modal message with random image and text.

pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/id/237/300/200").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x200>

# %%
img= Image(pil_image)

# %%
img
# Out:
# <img src="data:image/png;base64,..."/>

# %%
multi_modal_message= MultiModalMessage(content=["Can you describe the content of this image?", img], source="user")

# %%
multi_modal_message
# Out:
# MultiModalMessage(id='7066a6a7-8b41-47d0-b367-050261a605a9', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 20, 37, 116267, tzinfo=datetime.timezone.utc), content=['Can you describe the content of this image?', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage')

# %% [markdown]
# MultiModalMessage(id='7066a6a7-8b41-47d0-b367-050261a605a9', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 20, 37, 116267, tzinfo=datetime.timezone.utc), content=['Can you describe the content of this image?', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage')

# %% [markdown]
#  content=['Can you describe the content of this image?', <autogen_core._image.Image object at 0x000002C524BD0CE0>]

# %%
response= await my_assistant.run(task=multi_modal_message )

# %%
response
# Out:
# TaskResult(messages=[MultiModalMessage(id='7066a6a7-8b41-47d0-b367-050261a605a9', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 20, 37, 116267, tzinfo=datetime.timezone.utc), content=['Can you describe the content of this image?', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage'), TextMessage(id='c6445023-a68e-43db-8cdc-9592995f78ed', source='Assistant', models_usage=RequestUsage(prompt_tokens=500, completion_tokens=38), metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 25, 5, 968783, tzinfo=datetime.timezone.utc), content='The image shows a black Labrador Retriever puppy sitting on a wooden surface, looking up into the camera. The puppy has shiny, smooth fur and appears to be in a relaxed and curious pose.', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=[MultiModalMessage(id='7066a6a7-8b41-47d0-b367-050261a605a9', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 20, 37, 116267, tzinfo=datetime.timezone.utc), content=['Can you describe the content of this image?', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage'), TextMessage(id='c6445023-a68e-43db-8cdc-9592995f78ed', source='Assistant', models_usage=RequestUsage(prompt_tokens=500, completion_tokens=38), metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 25, 5, 968783, tzinfo=datetime.timezone.utc), content='The image shows a black Labrador Retriever puppy sitting on a wooden surface, looking up into the camera. The puppy has shiny, smooth fur and appears to be in a relaxed and curious pose.', type='TextMessage')], stop_reason=None)

# %% [markdown]
# content='The image shows a black Labrador Retriever puppy sitting on a wooden surface, looking up into the camera. The puppy has shiny, smooth fur and appears to be in a relaxed and curious pose.'

# %%
multi_modal_message= MultiModalMessage(content=["What is in the image", img], source="user")

# %%
response= await my_assistant.run(task=multi_modal_message)

# %%
response
# Out:
# TaskResult(messages=[MultiModalMessage(id='6547c516-88eb-4c81-963a-2364dc614791', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 25, 45, 916378, tzinfo=datetime.timezone.utc), content=['What is in the image', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage'), TextMessage(id='98ecdde4-02eb-47f9-b7e0-498df0695f9a', source='Assistant', models_usage=RequestUsage(prompt_tokens=807, completion_tokens=20), metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 26, 53, 690362, tzinfo=datetime.timezone.utc), content='The image features a black Labrador Retriever puppy sitting on a wooden surface, looking up at the camera.', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=[MultiModalMessage(id='6547c516-88eb-4c81-963a-2364dc614791', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 25, 45, 916378, tzinfo=datetime.timezone.utc), content=['What is in the image', <autogen_core._image.Image object at 0x000002C524BD0CE0>], type='MultiModalMessage'), TextMessage(id='98ecdde4-02eb-47f9-b7e0-498df0695f9a', source='Assistant', models_usage=RequestUsage(prompt_tokens=807, completion_tokens=20), metadata={}, created_at=datetime.datetime(2025, 7, 6, 12, 26, 53, 690362, tzinfo=datetime.timezone.utc), content='The image features a black Labrador Retriever puppy sitting on a wooden surface, looking up at the camera.', type='TextMessage')], stop_reason=None)

# %% [markdown]
# content='The image features a black Labrador Retriever puppy sitting on a wooden surface, looking up at the camera.'

# %%
agent_state= my_assistant.save_state()

# %%
agent_state # Not used await
# Out:
# <coroutine object AssistantAgent.save_state at 0x000002C524EE2330>

# %%
agent_state= await my_assistant.save_state()

# %%
agent_state
# Out:
# {'type': 'AssistantAgentState',
#  'version': '1.0.0',
#  'llm_context': {'messages': [{'content': 'Who are you?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
#    {'content': "Unfortunately, I can't recall past interactions or questions unless they're part of the current session. Is there anything else you'd like to know or ask?",
#     'thought': None,
#     'source': 'Assistant',
#     'type': 'AssistantMessage'},
#    {'content': 'What was the last question I asked?',
#     'source': 'user',
#     'type': 'UserMessage'},
# ...

# %% [markdown]
# <!-- Here's The Complete State Messages's conversation, By default Maintined by Autogen  -->
#
# 'content': 'Who are you?'
#
# 'content': "I am a virtual assistant designed to help you with a variety of tasks, such as answering questions, providing information, and assisting with problem-solving. If there's anything specific you need help with, feel free to ask!"
#
# 'content': 'What was the last question I asked?'
#
# 'content': "Unfortunately, I can't recall past interactions or questions unless they're part of the current session. Is there anything else you'd like to know or ask?"
#
# 'content': 'What was the last question I asked?'
#
# 'content': 'The last question you asked was, "Who are you?" Is there anything else I can assist you with?'
#
# 'content': 'what was the last two quesstions?'
#
# 'content': 'The last two questions you asked were:\n\n1. "Who are you?"\n2. "What was the last question I asked?"\n\nIf you have any more questions or need further assistance, feel free to ask!'
#
# 'content': ['Can you describe the content of this image?']
#
# 'content': 'The image shows a black Labrador Retriever puppy sitting on a wooden surface, looking up into the camera. The puppy has shiny, smooth fur and appears to be in a relaxed and curious pose.'
#
# 'content': ['What is in the image']
#
# 'content': 'The image features a black Labrador Retriever puppy sitting on a wooden surface, looking up at the camera.'

# %% [markdown]
# ### Static Random Image

# %%
pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/seed/picsum/200/300").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300>

# %% [markdown]
# ### Grayscale

# %%
pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/200/300?grayscale").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=200x300>

# %%
pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/id/1/200/300").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300>

# %%
pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/id/11/200/300").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300>

# %%
pil_image= PIL.Image.open(BytesIO(requests.get("https://picsum.photos/id/30/200/300").content))

# %%
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300>

# %%
img= Image(pil_image)

# %%
img
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ### Structure Model Client

# %%
from pydantic import BaseModel

# %%
class PlantInfo(BaseModel):
    name: str
    color: str
    distance: str

# %%
structured_model_client= OpenAIChatCompletionClient(
    model="gpt-4o",
    api_key=api_key,
    response_format=PlantInfo
)

# %%
structured_model_client

# %%
my_assistant2= AssistantAgent(name="Assistant2", model_client=structured_model_client)

# %%
response= await my_assistant2.run(task="who are you")

# %%
response
# Out:
# TaskResult(messages=[TextMessage(id='4dfc3659-be0d-4a4c-95bf-bbcbadcd986e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 40, 50632, tzinfo=datetime.timezone.utc), content='who are you', type='TextMessage'), TextMessage(id='361bae5c-b27c-4417-a1cd-cfddd743ddb2', source='Assistant2', models_usage=RequestUsage(prompt_tokens=96, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 41, 614886, tzinfo=datetime.timezone.utc), content='{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}', type='TextMessage')], stop_reason=None)

# %% [markdown]
# TaskResult(messages=
# [TextMessage(id='4dfc3659-be0d-4a4c-95bf-bbcbadcd986e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 40, 50632, tzinfo=datetime.timezone.utc), content='who are you', type='TextMessage'),
#
# TextMessage(id='361bae5c-b27c-4417-a1cd-cfddd743ddb2', source='Assistant2', models_usage=RequestUsage(prompt_tokens=96, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 41, 614886, tzinfo=datetime.timezone.utc), content='{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}', type='TextMessage')], stop_reason=None)

# %% [markdown]
# content='{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}'

# %%
response.messages[-1]
# Out:
# TextMessage(id='361bae5c-b27c-4417-a1cd-cfddd743ddb2', source='Assistant2', models_usage=RequestUsage(prompt_tokens=96, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 41, 614886, tzinfo=datetime.timezone.utc), content='{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}', type='TextMessage')

# %% [markdown]
# TextMessage(id='361bae5c-b27c-4417-a1cd-cfddd743ddb2', source='Assistant2', models_usage=RequestUsage(prompt_tokens=96, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 6, 13, 4, 41, 614886, tzinfo=datetime.timezone.utc), content='{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}', type='TextMessage')

# %%
response.messages[-1].content
# Out:
# '{"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}'

# %%
result= response.messages[-1].content

# %%
print(result)
# Out:
# {"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}

# %% [markdown]
# {"name":"Venus Flytrap","color":"Green","distance":"Eastern United States"}
