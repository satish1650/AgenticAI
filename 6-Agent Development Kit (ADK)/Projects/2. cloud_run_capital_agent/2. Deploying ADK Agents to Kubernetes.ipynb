# %% [markdown]
# ---
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# # Deploy to Google Kubernetes Engine (GKE) 👉 [Learn more](https://google.github.io/adk-docs/deploy/gke/#environment-variables)
# ## Deploy to Cloud Run
# [GKE](https://cloud.google.com/kubernetes-engine?hl=en) is the Google Cloud managed Kubernetes service. It allows you to deploy and manage containerized applications using Kubernetes. <br>
#
# To deploy your agent you will need to have a Kubernetes cluster running on GKE. You can create a cluster using the Google Cloud Console or the gcloud command line tool.
#
# ## Deploying your Agent
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----

# %% [markdown]
# ### Deploy the Application
#
# ### `We can navigate to the external IP and interact with the agent via UI`
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ----

# %% [markdown]
# ## Google Kubernetes Engine (GKE)  👉 [Learn more](https://cloud.google.com/kubernetes-engine?hl=en)
# ![image-4.png](attachment:image-4.png) <br> ![image-5.png](attachment:image-5.png)
#
# ### Google Kubernetes Engine documentation 👉 [Read the docs](https://cloud.google.com/kubernetes-engine/docs)
# ![image.png](attachment:image.png)
#
# ### 👉 [Kubernetes-comic](https://cloud.google.com/kubernetes-engine/kubernetes-comic)
# ![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)
# ---

# %% [markdown]
# ---
