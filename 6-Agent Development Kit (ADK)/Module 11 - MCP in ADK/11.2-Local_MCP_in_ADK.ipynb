# %% [markdown]
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# # Local MCP in ADK
# ## 1. If you are using External Tools/Application ---> Got with `MCP`
# ## 2. If internal tool which will not be used a lot across ---> Tools works
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---
#
# ![image-2.png](attachment:image-2.png) <br><br>
#
# ![image-3.png](attachment:image-3.png)
#
# # [Learn more](https://modelcontextprotocol.io/docs/getting-started/intro)
#
# ---
# ## Architecture overview
# ![image-7.png](attachment:image-7.png) <br><br>
# ![image-8.png](attachment:image-8.png) <br>
# ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png) <br><br>
#
# ![image-11.png](attachment:image-11.png)
#
# ---
# ## Connect to local MCP servers
# ![image-4.png](attachment:image-4.png)
#
# ### Configure the Filesystem Server
# Replace the contents of the configuration file with the following JSON structure. This configuration tells Claude Desktop to start the Filesystem Server with access to specific directories:
#
# ### `Windows`
# ```Python
# {
#   "mcpServers": {
#     "filesystem": {
#       "command": "npx",
#       "args": [
#         "-y",
#         "@modelcontextprotocol/server-filesystem",
#         "C:\\Users\\username\\Desktop",
#         "C:\\Users\\username\\Downloads"
#       ]
#     }
#   }
# }
# ```
#
# ![image-5.png](attachment:image-5.png)
#
# ---
#
# ## Connect to remote MCP Servers
# ![image-6.png](attachment:image-6.png) <br><br> ![image-12.png](attachment:image-12.png) <br><br> ![image-13.png](attachment:image-13.png) <br><br>
# ![image-14.png](attachment:image-14.png)![image-15.png](attachment:image-15.png)
#
# ----

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ----
#
# ![image-2.png](attachment:image-2.png)
#
# # 👉 [Learn More](https://gofastmcp.com/getting-started/welcome)
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ----
#
# ![image-2.png](attachment:image-2.png)
#
# # 👉 [Learn more](https://www.postman.com/explore/mcp-servers)

# %% [markdown]
# ----
